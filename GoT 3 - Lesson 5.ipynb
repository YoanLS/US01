# %% [markdown]
# # GAME OF THRONES: A GRAPH EXPERIMENT
# ## get the extracted characters informations from pickles
# The dictionaries are loaded directly

# %%
import pickle
with open('characters.pickle','rb') as fp:
    characters = pickle.load(fp)
characters
# Out:
# [{'short_name': 'Sumner Crakehall',
#   'common_name': 'Sumner Crakehall',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4],
#   'url': 'Sumner_Crakehall'},
#  {'short_name': None,
#   'common_name': 'Lamprey',
#   'fullname': None,
#   'aliases': ['Lamprey'],
#   'books': [3],
#   'url': 'Lamprey'},
#  {'short_name': 'Rhaego',
#   'common_name': 'Rhaego',
#   'fullname': None,
#   'aliases': ['The stallion who mounts the world'],
#   'books': [1, 2, 3, 4],
#   'url': 'Rhaego'},
#  {'short_name': 'Jeyne Waters',
#   'common_name': 'Jeyne Waters',
#   'fullname': None,
#   'aliases': None,
#   'books': [],
#   'url': 'Jeyne_Waters'},
#  {'short_name': 'Sybell Spicer',
#   'common_name': 'Sybell Spicer',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4],
#   'url': 'Sybell_Spicer'},
#  {'short_name': 'Dennett',
#   'common_name': 'Dennet',
#   'fullname': None,
#   'aliases': None,
#   'books': [3],
#   'url': 'Dennet'},
#  {'short_name': 'Lord Ashford',
#   'common_name': 'Lord Ashford',
#   'fullname': None,
#   'aliases': None,
#   'books': [],
#   'url': 'Lord_Ashford'},
#  {'short_name': 'Selyse Florent',
#   'common_name': 'Selyse Florent',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Selyse_Florent'},
#  {'short_name': 'Humfrey Beesbury',
#   'common_name': 'Humfrey Beesbury',
#   'fullname': None,
#   'aliases': None,
#   'books': [],
#   'url': 'Humfrey_Beesbury'},
#  {'short_name': 'Jayde',
#   'common_name': 'Jayde',
#   'fullname': None,
#   'aliases': None,
#   'books': [3],
#   'url': 'Jayde'},
#  {'short_name': 'Robin Hollard',
#   'common_name': 'Robin Hollard',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Robin_Hollard'},
#  {'short_name': 'Dunaver',
#   'common_name': 'Dunaver',
#   'fullname': None,
#   'aliases': None,
#   'books': [2],
#   'url': 'Dunaver'},
#  {'short_name': 'Esgred',
#   'common_name': 'Esgred',
#   'fullname': None,
#   'aliases': None,
#   'books': [2],
#   'url': 'Esgred'},
#  {'short_name': 'Lewyn Martell',
#   'common_name': 'Lewyn Martell',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 3, 4, 5],
#   'url': 'Lewyn_Martell'},
#  {'short_name': 'Samwell Spicer',
#   'common_name': 'Samwell Spicer',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4],
#   'url': 'Samwell_Spicer'},
#  {'short_name': 'Kella',
#   'common_name': 'Kella',
#   'fullname': None,
#   'aliases': None,
#   'books': [3],
#   'url': 'Kella'},
#  {'short_name': 'Gormon Peake',
#   'common_name': 'Gormon Peake',
#   'fullname': None,
#   'aliases': ['Gormy'],
#   'books': [],
#   'url': 'Gormon_Peake'},
#  {'short_name': 'Godry Farring',
#   'common_name': 'Godry Farring',
#   'fullname': None,
#   'aliases': ['Godry the Giantslayer'],
#   'books': [4, 5],
#   'url': 'Godry_Farring'},
#  {'short_name': 'Wyl',
#   'common_name': 'Wyl (guard)',
#   'fullname': None,
#   'aliases': None,
#   'books': [1],
#   'url': 'Wyl_(guard)'},
#  {'short_name': 'Ollo',
#   'common_name': 'Ollo Lophand',
#   'fullname': None,
#   'aliases': ['Ollo Lophand'],
#   'books': [3, 4, 5],
#   'url': 'Ollo_Lophand'},
#  {'short_name': 'Ferrego Antaryon',
#   'common_name': 'Ferrego Antaryon',
#   'fullname': None,
#   'aliases': None,
#   'books': [4, 5],
#   'url': 'Ferrego_Antaryon'},
#  {'short_name': 'Anders Yronwood',
#   'common_name': 'Anders Yronwood',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4, 5],
#   'url': 'Anders_Yronwood'},
#  {'short_name': 'Lomas Estermont',
#   'common_name': 'Lomas Estermont',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4, 5],
#   'url': 'Lomas_Estermont'},
#  {'short_name': 'Hoke',
#   'common_name': 'Hoke',
#   'fullname': None,
#   'aliases': ['Hoke the Horseleg'],
#   'books': [4],
#   'url': 'Hoke'},
#  {'short_name': 'Edwyd Fossoway',
#   'common_name': 'Edwyd Fossoway',
#   'fullname': None,
#   'aliases': None,
#   'books': [2],
#   'url': 'Edwyd_Fossoway'},
#  {'short_name': 'Leyla Hightower',
#   'common_name': 'Leyla Hightower',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Leyla_Hightower'},
#  {'short_name': 'Hugo Wull',
#   'common_name': 'Hugo Wull',
#   'fullname': None,
#   'aliases': ['Big Bucket', 'Big Bucket Wull'],
#   'books': [4, 5],
#   'url': 'Hugo_Wull'},
#  {'short_name': 'Terrence Kenning',
#   'common_name': 'Terrence Kenning',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4, 5],
#   'url': 'Terrence_Kenning'},
#  {'short_name': 'Walton Frey',
#   'common_name': 'Walton Frey',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4],
#   'url': 'Walton_Frey'},
#  {'short_name': 'Galbart Glover',
#   'common_name': 'Galbart Glover',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Galbart_Glover'},
#  {'short_name': 'Beck',
#   'common_name': 'Beck',
#   'fullname': None,
#   'aliases': None,
#   'books': [3],
#   'url': 'Beck'},
#  {'short_name': 'Valarr Targaryen',
#   'common_name': 'Valarr Targaryen',
#   'fullname': None,
#   'aliases': ['The Young Prince'],
#   'books': [],
#   'url': 'Valarr_Targaryen'},
#  {'short_name': 'Chayle',
#   'common_name': 'Chayle',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3],
#   'url': 'Chayle'},
#  {'short_name': 'Hoster Frey',
#   'common_name': 'Hoster Frey',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4],
#   'url': 'Hoster_Frey'},
#  {'short_name': 'Cerenna Lannister',
#   'common_name': 'Cerenna Lannister',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Cerenna_Lannister'},
#  {'short_name': 'Quenton Greyjoy',
#   'common_name': 'Quenton Greyjoy',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Quenton_Greyjoy'},
#  {'short_name': 'Leslyn Haigh',
#   'common_name': 'Leslyn Haigh',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4, 5],
#   'url': 'Leslyn_Haigh'},
#  {'short_name': 'Ronnel Stout',
#   'common_name': 'Ronnel Stout',
#   'fullname': None,
#   'aliases': None,
#   'books': [3],
#   'url': 'Ronnel_Stout'},
#  {'short_name': 'Robb Reyne',
#   'common_name': 'Robb Reyne',
#   'fullname': None,
#   'aliases': None,
#   'books': [],
#   'url': 'Robb_Reyne'},
#  {'short_name': 'Jon Cupps',
#   'common_name': 'Jon Cupps',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Jon_Cupps'},
#  {'short_name': 'Andar Royce',
#   'common_name': 'Andar Royce',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Andar_Royce'},
#  {'short_name': 'Gelmarr',
#   'common_name': 'Gelmarr',
#   'fullname': None,
#   'aliases': ['The Grim'],
#   'books': [2, 5],
#   'url': 'Gelmarr'},
#  {'short_name': 'Dunstan Drumm',
#   'common_name': 'Dunstan Drumm',
#   'fullname': None,
#   'aliases': ['The Drumm', 'Bone Hand'],
#   'books': [2, 3, 4, 5],
#   'url': 'Dunstan_Drumm'},
#  {'short_name': 'Beren Tallhart',
#   'common_name': 'Beren Tallhart',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4, 5],
#   'url': 'Beren_Tallhart'},
#  {'short_name': 'Denys Drumm',
#   'common_name': 'Denys Drumm',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Denys_Drumm'},
#  {'short_name': 'Ryella Frey',
#   'common_name': 'Ryella Frey',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4],
#   'url': 'Ryella_Frey'},
#  {'short_name': 'Gladden Wylde',
#   'common_name': 'Gladden Wylde',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 3],
#   'url': 'Gladden_Wylde'},
#  {'short_name': 'Mychel Redfort',
#   'common_name': 'Mychel Redfort',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Mychel_Redfort'},
#  {'short_name': 'Philip Foote',
#   'common_name': 'Philip Foote',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 5],
#   'url': 'Philip_Foote'},
#  {'short_name': 'Shiera Seastar',
#   'common_name': 'Shiera Seastar',
#   'fullname': None,
#   'aliases': None,
#   'books': [5],
#   'url': 'Shiera_Seastar'},
#  {'short_name': 'Humfrey Clifton',
#   'common_name': 'Humfrey Clifton',
#   'fullname': None,
#   'aliases': None,
#   'books': [5],
#   'url': 'Humfrey_Clifton'},
#  {'short_name': 'Ygritte',
#   'common_name': 'Ygritte',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4, 5],
#   'url': 'Ygritte'},
#  {'short_name': 'Emphyria Vance',
#   'common_name': 'Emphyria Vance',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Emphyria_Vance'},
#  {'short_name': 'Greydon Goodbrother',
#   'common_name': 'Greydon Goodbrother',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Greydon_Goodbrother'},
#  {'short_name': 'Rickard Tyrell',
#   'common_name': 'Rickard Tyrell',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4],
#   'url': 'Rickard_Tyrell'},
#  {'short_name': 'Karlon Stark',
#   'common_name': 'Karlon Stark',
#   'fullname': None,
#   'aliases': None,
#   'books': [3],
#   'url': 'Karlon_Stark'},
#  {'short_name': 'Ronel Rivers',
#   'common_name': 'Ronel Rivers',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Ronel_Rivers'},
#  {'short_name': 'Dywen',
#   'common_name': 'Dywen',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Dywen'},
#  {'short_name': 'Brandon Stark',
#   'common_name': 'Brandon Stark',
#   'fullname': None,
#   'aliases': ['The Wild Wolf'],
#   'books': [1, 2, 3, 5],
#   'url': 'Brandon_Stark'},
#  {'short_name': 'Roger Hogg',
#   'common_name': 'Roger Hogg',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Roger_Hogg'},
#  {'short_name': 'Three Toes',
#   'common_name': 'Three Toes',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4],
#   'url': 'Three_Toes'},
#  {'short_name': 'Olyvar Frey',
#   'common_name': 'Olyvar Frey',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Olyvar_Frey'},
#  {'short_name': 'Jorah Mormont',
#   'common_name': 'Jorah Mormont',
#   'fullname': None,
#   'aliases': ['The exile knight', 'Jorah the Andal', 'Ser Bezoar'],
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Jorah_Mormont'},
#  {'short_name': 'Brynden Tully',
#   'common_name': 'Brynden Tully',
#   'fullname': None,
#   'aliases': ['Brynden the Blackfish',
#    'Brynden Blackfish',
#    'Blackfish',
#    'Uncle Brynden'],
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Brynden_Tully'},
#  {'short_name': 'Gariss',
#   'common_name': 'Gariss',
#   'fullname': None,
#   'aliases': None,
#   'books': [2],
#   'url': 'Gariss'},
#  {'short_name': 'Yellow Dick',
#   'common_name': 'Yellow Dick',
#   'fullname': None,
#   'aliases': None,
#   'books': [5],
#   'url': 'Yellow_Dick'},
#  {'short_name': 'Willam Wells',
#   'common_name': 'Willam Wells',
#   'fullname': None,
#   'aliases': None,
#   'books': [5],
#   'url': 'Willam_Wells'},
#  {'short_name': 'Darlessa Marbrand',
#   'common_name': 'Darlessa Marbrand',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3, 5],
#   'url': 'Darlessa_Marbrand'},
#  {'short_name': 'Rosamund Lannister',
#   'common_name': 'Rosamund Lannister',
#   'fullname': None,
#   'aliases': None,
#   'books': [4, 5],
#   'url': 'Rosamund_Lannister'},
#  {'short_name': 'Walder Vance',
#   'common_name': 'Walder Vance',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4],
#   'url': 'Walder_Vance'},
#  {'short_name': 'Lyonel Tyrell',
#   'common_name': 'Lyonel Tyrell (lord)',
#   'fullname': None,
#   'aliases': None,
#   'books': [],
#   'url': 'Lyonel_Tyrell_(lord)'},
#  {'short_name': None,
#   'common_name': 'House Osgrey',
#   'fullname': None,
#   'aliases': None,
#   'books': None,
#   'url': 'House_Osgrey'},
#  {'short_name': 'Kegs',
#   'common_name': 'Kegs',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4, 5],
#   'url': 'Kegs'},
#  {'short_name': 'Hizdahr zo Loraq',
#   'common_name': 'Hizdahr zo Loraq',
#   'fullname': 'Hizdahr zo Loraq, Fourteenth of That Noble Name[1]',
#   'aliases': ['Hizdak', 'Hizdahr of the tepid kisses'],
#   'books': None,
#   'url': 'Hizdahr_zo_Loraq'},
#  {'short_name': 'Alyn Ambrose',
#   'common_name': 'Alyn Ambrose',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4, 5],
#   'url': 'Alyn_Ambrose'},
#  {'short_name': 'Melisandre',
#   'common_name': 'Melisandre',
#   'fullname': None,
#   'aliases': ['The red woman',
#    'Red witch',
#    "The king's red shadow",
#    'Lady Red',
#    'Melony'],
#   'books': [2, 3, 4, 5],
#   'url': 'Melisandre'},
#  {'short_name': 'Ossy',
#   'common_name': 'Ossy',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Ossy'},
#  {'short_name': 'Malleon',
#   'common_name': 'Malleon',
#   'fullname': None,
#   'aliases': None,
#   'books': [1],
#   'url': 'Malleon'},
#  {'short_name': 'Jafer Flowers',
#   'common_name': 'Jafer Flowers',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2],
#   'url': 'Jafer_Flowers'},
#  {'short_name': 'Moribald Chester',
#   'common_name': 'Moribald Chester',
#   'fullname': None,
#   'aliases': None,
#   'books': [4, 5],
#   'url': 'Moribald_Chester'},
#  {'short_name': 'Gavin',
#   'common_name': 'Gavin',
#   'fullname': None,
#   'aliases': ['Gavin the Trader'],
#   'books': [5],
#   'url': 'Gavin'},
#  {'short_name': 'Sherrit',
#   'common_name': 'Sherrit',
#   'fullname': None,
#   'aliases': None,
#   'books': [3],
#   'url': 'Sherrit'},
#  {'short_name': 'Kennos of Kayce',
#   'common_name': 'Kennos of Kayce',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4, 5],
#   'url': 'Kennos_of_Kayce'},
#  {'short_name': 'Arnell',
#   'common_name': 'Arnell',
#   'fullname': None,
#   'aliases': None,
#   'books': [2],
#   'url': 'Arnell'},
#  {'short_name': 'Rhaenys Targaryen',
#   'common_name': 'Rhaenys Targaryen (daughter of Aemon)',
#   'fullname': None,
#   'aliases': ['The Queen Who Never Was'],
#   'books': [],
#   'url': 'Rhaenys_Targaryen_(daughter_of_Aemon)'},
#  {'short_name': 'Vickon Greyjoy',
#   'common_name': 'Vickon Greyjoy',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 4, 5],
#   'url': 'Vickon_Greyjoy'},
#  {'short_name': 'Gawen Westerling',
#   'common_name': 'Gawen Westerling',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Gawen_Westerling'},
#  {'short_name': 'Garth Greenfield',
#   'common_name': 'Garth Greenfield',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 3, 4, 5],
#   'url': 'Garth_Greenfield'},
#  {'short_name': 'Grazdan mo Eraz',
#   'common_name': 'Grazdan mo Eraz',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4, 5],
#   'url': 'Grazdan_mo_Eraz'},
#  {'short_name': 'Sefton Staunton',
#   'common_name': 'Sefton Staunton',
#   'fullname': None,
#   'aliases': None,
#   'books': [],
#   'url': 'Sefton_Staunton'},
#  {'short_name': 'Chiggen',
#   'common_name': 'Chiggen',
#   'fullname': None,
#   'aliases': None,
#   'books': [1],
#   'url': 'Chiggen'},
#  {'short_name': 'Draqaz',
#   'common_name': 'Draqaz',
#   'fullname': None,
#   'aliases': None,
#   'books': [5],
#   'url': 'Draqaz'},
#  {'short_name': 'Mullin',
#   'common_name': 'Mullin',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4, 5],
#   'url': 'Mullin'},
#  {'short_name': 'Gascoyne',
#   'common_name': 'Gascoyne',
#   'fullname': None,
#   'aliases': ['Gascoyne of the Greenblood'],
#   'books': [4, 5],
#   'url': 'Gascoyne'},
#  {'short_name': 'Tansy',
#   'common_name': 'Tansy (orphan)',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Tansy_(orphan)'},
#  {'short_name': 'Pate',
#   'common_name': 'Pate of the Blue Fork',
#   'fullname': None,
#   'aliases': ['Pate of the Blue Fork Pate of Sevenstreams'],
#   'books': [2, 3, 4],
#   'url': 'Pate_of_the_Blue_Fork'},
#  {'short_name': 'Grazdan zo Galare',
#   'common_name': 'Grazdan zo Galare',
#   'fullname': None,
#   'aliases': None,
#   'books': [5],
#   'url': 'Grazdan_zo_Galare'},
#  {'short_name': 'Pate',
#   'common_name': 'Pate (Old)',
#   'fullname': None,
#   'aliases': ['Old Pate'],
#   'books': [3],
#   'url': 'Pate_(Old)'},
#  {'short_name': 'Jorquen',
#   'common_name': 'Jorquen',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Jorquen'},
#  {'short_name': 'Benjen Stark',
#   'common_name': 'Benjen Stark (Bitter)',
#   'fullname': 'Benjen Stark',
#   'aliases': ['Benjen the Bitter'],
#   'books': None,
#   'url': 'Benjen_Stark_(Bitter)'},
#  {'short_name': 'Balaq',
#   'common_name': 'Black Balaq',
#   'fullname': None,
#   'aliases': ['Black Balaq'],
#   'books': [5],
#   'url': 'Black_Balaq'},
#  {'short_name': 'Daemon II Blackfyre',
#   'common_name': 'Daemon II Blackfyre',
#   'fullname': None,
#   'aliases': ['Ser John the Fiddler',
#    'Daemon the Younger',
#    'The Brown Dragon'],
#   'books': [],
#   'url': 'Daemon_II_Blackfyre'},
#  {'short_name': 'Jon Arryn',
#   'common_name': 'Jon Arryn',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Jon_Arryn'},
#  {'short_name': 'Beric Dondarrion',
#   'common_name': 'Beric Dondarrion',
#   'fullname': None,
#   'aliases': ['Lord Derik',
#    "Wisp o' the wood",
#    'The lightning lord',
#    'The scarecrow knight',
#    'The Lord of Corpses'],
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Beric_Dondarrion'},
#  {'short_name': 'Raymun Darry',
#   'common_name': 'Raymun Darry',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 3, 4],
#   'url': 'Raymun_Darry'},
#  {'short_name': 'Dalla',
#   'common_name': 'Dalla',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4, 5],
#   'url': 'Dalla'},
#  {'short_name': 'Bloodbeard',
#   'common_name': 'Bloodbeard',
#   'fullname': None,
#   'aliases': None,
#   'books': [5],
#   'url': 'Bloodbeard'},
#  {'short_name': 'Rodrik Ryswell',
#   'common_name': 'Rodrik Ryswell',
#   'fullname': None,
#   'aliases': None,
#   'books': [4, 5],
#   'url': 'Rodrik_Ryswell'},
#  {'short_name': 'Tremond Gargalen',
#   'common_name': 'Tremond Gargalen',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4, 5],
#   'url': 'Tremond_Gargalen'},
#  {'short_name': 'Rodrik Greyjoy',
#   'common_name': 'Rodrik Greyjoy',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Rodrik_Greyjoy'},
#  {'short_name': 'Gerold Dayne',
#   'common_name': 'Gerold Dayne',
#   'fullname': None,
#   'aliases': ['Darkstar'],
#   'books': [4, 5],
#   'url': 'Gerold_Dayne'},
#  {'short_name': 'Tim Stone',
#   'common_name': 'Tim Stone',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4, 5],
#   'url': 'Tim_Stone'},
#  {'short_name': 'Myrcella Baratheon',
#   'common_name': 'Myrcella Baratheon',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Myrcella_Baratheon'},
#  {'short_name': 'Benjen Stark',
#   'common_name': 'Benjen Stark',
#   'fullname': None,
#   'aliases': ['Uncle Benjen', 'Ben Stark', 'The young pup'],
#   'books': [1, 2, 3, 5],
#   'url': 'Benjen_Stark'},
#  {'short_name': 'Elbert Arryn',
#   'common_name': 'Elbert Arryn',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 4],
#   'url': 'Elbert_Arryn'},
#  {'short_name': 'Garth XII Gardener',
#   'common_name': 'Garth XII Gardener',
#   'fullname': 'Garth of House Gardener, the Twelfth of His Name',
#   'aliases': None,
#   'books': None,
#   'url': 'Garth_XII_Gardener'},
#  {'short_name': None,
#   'common_name': 'Last Hearth',
#   'fullname': None,
#   'aliases': None,
#   'books': None,
#   'url': 'Last_Hearth'},
#  {'short_name': 'Umar',
#   'common_name': 'Umar',
#   'fullname': None,
#   'aliases': None,
#   'books': [1],
#   'url': 'Umar'},
#  {'short_name': 'Amarei Crakehall',
#   'common_name': 'Amarei Crakehall',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4, 5],
#   'url': 'Amarei_Crakehall'},
#  {'short_name': 'Val',
#   'common_name': 'Val',
#   'fullname': None,
#   'aliases': ['The wildling princess', 'Lady Val'],
#   'books': [3, 4, 5],
#   'url': 'Val'},
#  {'short_name': 'Grazhar zo Galare',
#   'common_name': 'Grazhar zo Galare',
#   'fullname': None,
#   'aliases': ['Grazdar'],
#   'books': [5],
#   'url': 'Grazhar_zo_Galare'},
#  {'short_name': 'Emmond',
#   'common_name': 'Emmond',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Emmond'},
#  {'short_name': 'Courteny Greenhill',
#   'common_name': 'Courtenay Greenhill',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Courtenay_Greenhill'},
#  {'short_name': 'Vargo Hoat',
#   'common_name': 'Vargo Hoat',
#   'fullname': None,
#   'aliases': ['The Qohorik',
#    'The Crippler',
#    'The goat',
#    'The goat-helm',
#    'The Goat of Harrenhal',
#    'The Goat'],
#   'books': [1, 2, 3, 4],
#   'url': 'Vargo_Hoat'},
#  {'short_name': None,
#   'common_name': 'Winterfell',
#   'fullname': None,
#   'aliases': None,
#   'books': None,
#   'url': 'Winterfell'},
#  {'short_name': 'Bryen Caron',
#   'common_name': 'Bryen Caron',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4],
#   'url': 'Bryen_Caron'},
#  {'short_name': 'Bearded Ben',
#   'common_name': 'Bearded Ben',
#   'fullname': None,
#   'aliases': None,
#   'books': [4, 5],
#   'url': 'Bearded_Ben'},
#  {'short_name': 'Harwood Fell',
#   'common_name': 'Harwood Fell',
#   'fullname': None,
#   'aliases': None,
#   'books': [4, 5],
#   'url': 'Harwood_Fell'},
#  {'short_name': 'Reynard Webber',
#   'common_name': 'Reynard Webber',
#   'fullname': None,
#   'aliases': None,
#   'books': [],
#   'url': 'Reynard_Webber'},
#  {'short_name': None,
#   'common_name': "Sack of King's Landing",
#   'fullname': None,
#   'aliases': None,
#   'books': None,
#   'url': 'Sack_of_King%27s_Landing'},
#  {'short_name': 'Rusty Flowers',
#   'common_name': 'Rusty Flowers',
#   'fullname': None,
#   'aliases': None,
#   'books': [5],
#   'url': 'Rusty_Flowers'},
#  {'short_name': 'Sedgekins',
#   'common_name': 'Sedgekins',
#   'fullname': None,
#   'aliases': None,
#   'books': [3],
#   'url': 'Sedgekins'},
#  {'short_name': 'Castos',
#   'common_name': 'Castos',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Castos'},
#  {'short_name': 'Arys Oakheart',
#   'common_name': 'Arys Oakheart',
#   'fullname': None,
#   'aliases': ['The white knight'],
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Arys_Oakheart'},
#  {'short_name': 'Alannys Harlaw',
#   'common_name': 'Alannys Harlaw',
#   'fullname': None,
#   'aliases': ['Lanny'],
#   'books': [1, 2, 4, 5],
#   'url': 'Alannys_Harlaw'},
#  {'short_name': 'Walder Frey',
#   'common_name': 'Walder Frey (son of Jammos)',
#   'fullname': None,
#   'aliases': ['Big Walder'],
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Walder_Frey_(son_of_Jammos)'},
#  {'short_name': 'Luke',
#   'common_name': 'Likely Luke',
#   'fullname': None,
#   'aliases': ['Likely Luke'],
#   'books': [3, 4],
#   'url': 'Likely_Luke'},
#  {'short_name': 'Harwin',
#   'common_name': 'Harwin',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Harwin'},
#  {'short_name': None,
#   'common_name': 'Golden Company',
#   'fullname': None,
#   'aliases': None,
#   'books': None,
#   'url': 'Golden_Company'},
#  {'short_name': 'Eddison Tollet',
#   'common_name': 'Eddison Tollett',
#   'fullname': None,
#   'aliases': ['Dolorous Edd'],
#   'books': [2, 3, 4, 5],
#   'url': 'Eddison_Tollett'},
#  {'short_name': 'Jonos Stark',
#   'common_name': 'Jonos Stark',
#   'fullname': None,
#   'aliases': None,
#   'books': [2],
#   'url': 'Jonos_Stark'},
#  {'short_name': None,
#   'common_name': 'Bloody Gate',
#   'fullname': None,
#   'aliases': None,
#   'books': None,
#   'url': 'Bloody_Gate'},
#  {'short_name': None,
#   'common_name': 'Highgarden',
#   'fullname': None,
#   'aliases': None,
#   'books': None,
#   'url': 'Highgarden'},
#  {'short_name': 'Sebaston Farman',
#   'common_name': 'Sebaston Farman',
#   'fullname': None,
#   'aliases': None,
#   'books': [4, 5],
#   'url': 'Sebaston_Farman'},
#  {'short_name': 'Myles Mooton',
#   'common_name': 'Myles Mooton',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4],
#   'url': 'Myles_Mooton'},
#  {'short_name': 'Myrtle',
#   'common_name': 'Myrtle',
#   'fullname': None,
#   'aliases': None,
#   'books': [5],
#   'url': 'Myrtle'},
#  {'short_name': 'Ezzara',
#   'common_name': 'Ezzara',
#   'fullname': None,
#   'aliases': None,
#   'books': [5],
#   'url': 'Ezzara'},
#  {'short_name': 'Theon Stark',
#   'common_name': 'Theon Stark',
#   'fullname': None,
#   'aliases': ['The Hungry Wolf'],
#   'books': None,
#   'url': 'Theon_Stark'},
#  {'short_name': 'Jorah Stark',
#   'common_name': 'Jorah Stark',
#   'fullname': None,
#   'aliases': None,
#   'books': [2],
#   'url': 'Jorah_Stark'},
#  {'short_name': 'Red Oarsman',
#   'common_name': 'Red Oarsman',
#   'fullname': None,
#   'aliases': None,
#   'books': [4, 5],
#   'url': 'Red_Oarsman'},
#  {'short_name': 'Satin',
#   'common_name': 'Satin',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4, 5],
#   'url': 'Satin'},
#  {'short_name': 'Rugen',
#   'common_name': 'Rugen',
#   'fullname': None,
#   'aliases': ['Varys'],
#   'books': [1, 3, 4],
#   'url': 'Rugen'},
#  {'short_name': 'Clarence Crabb',
#   'common_name': 'Clarence Crabb',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Clarence_Crabb'},
#  {'short_name': 'Wat',
#   'common_name': 'Blue Bard',
#   'fullname': None,
#   'aliases': ['Blue Bard'],
#   'books': [4, 5],
#   'url': 'Blue_Bard'},
#  {'short_name': 'Gyloro Dothare',
#   'common_name': 'Gyloro Dothare',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Gyloro_Dothare'},
#  {'short_name': 'Horas Redwyne',
#   'common_name': 'Horas Redwyne',
#   'fullname': None,
#   'aliases': ['Horror'],
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Horas_Redwyne'},
#  {'short_name': 'Triston Sunderland',
#   'common_name': 'Triston Sunderland',
#   'fullname': None,
#   'aliases': None,
#   'books': [4, 5],
#   'url': 'Triston_Sunderland'},
#  {'short_name': 'Lucantine Woodwright',
#   'common_name': 'Lucantine Woodwright',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Lucantine_Woodwright'},
#  {'short_name': 'Violet',
#   'common_name': 'Violet',
#   'fullname': None,
#   'aliases': None,
#   'books': [3],
#   'url': 'Violet'},
#  {'short_name': 'Theodan Wells',
#   'common_name': 'Theodan Wells',
#   'fullname': None,
#   'aliases': ['Theodan the True'],
#   'books': [4, 5],
#   'url': 'Theodan_Wells'},
#  {'short_name': 'Bannen',
#   'common_name': 'Bannen',
#   'fullname': None,
#   'aliases': None,
#   'books': [3],
#   'url': 'Bannen'},
#  {'short_name': 'Terrence Toyne',
#   'common_name': 'Terrence Toyne',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4, 5],
#   'url': 'Terrence_Toyne'},
#  {'short_name': 'Trystane Martell',
#   'common_name': 'Trystane Martell',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Trystane_Martell'},
#  {'short_name': 'Morrec',
#   'common_name': 'Morrec',
#   'fullname': None,
#   'aliases': None,
#   'books': [1],
#   'url': 'Morrec'},
#  {'short_name': 'Renfred Rykker',
#   'common_name': 'Renfred Rykker',
#   'fullname': None,
#   'aliases': None,
#   'books': [4, 5],
#   'url': 'Renfred_Rykker'},
#  {'short_name': 'Grisel',
#   'common_name': 'Grisel',
#   'fullname': None,
#   'aliases': None,
#   'books': [3],
#   'url': 'Grisel'},
#  {'short_name': 'Colin Florent',
#   'common_name': 'Colin Florent',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4],
#   'url': 'Colin_Florent'},
#  {'short_name': 'Doran Martell',
#   'common_name': 'Doran Martell',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Doran_Martell'},
#  {'short_name': 'Endrew Tarth',
#   'common_name': 'Endrew Tarth',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3],
#   'url': 'Endrew_Tarth'},
#  {'short_name': 'Ellery Vance',
#   'common_name': 'Ellery Vance',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4],
#   'url': 'Ellery_Vance'},
#  {'short_name': 'Meralyn',
#   'common_name': 'Meralyn',
#   'fullname': None,
#   'aliases': ['Merry'],
#   'books': [4],
#   'url': 'Meralyn'},
#  {'short_name': 'Urzen',
#   'common_name': 'Urzen',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3],
#   'url': 'Urzen'},
#  {'short_name': 'Orivel',
#   'common_name': 'Orivel',
#   'fullname': None,
#   'aliases': ['Orivel the Open-Handed'],
#   'books': [4],
#   'url': 'Orivel'},
#  {'short_name': 'Hullen',
#   'common_name': 'Hullen',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3, 5],
#   'url': 'Hullen'},
#  {'short_name': None,
#   'common_name': 'Dragonstone',
#   'fullname': None,
#   'aliases': None,
#   'books': None,
#   'url': 'Dragonstone'},
#  {'short_name': None,
#   'common_name': 'Deepwood Motte',
#   'fullname': None,
#   'aliases': None,
#   'books': None,
#   'url': 'Deepwood_Motte'},
#  {'short_name': 'Carrot',
#   'common_name': 'Carrot',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Carrot'},
#  {'short_name': 'Allaquo',
#   'common_name': 'Allaquo',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Allaquo'},
#  {'short_name': 'Sarya Whent',
#   'common_name': 'Sarya Whent',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4, 5],
#   'url': 'Sarya_Whent'},
#  {'short_name': 'Uthor Underleaf',
#   'common_name': 'Uthor Underleaf',
#   'fullname': None,
#   'aliases': ['The Snail'],
#   'books': [],
#   'url': 'Uthor_Underleaf'},
#  {'short_name': 'Gilwood Hunter',
#   'common_name': 'Gilwood Hunter',
#   'fullname': None,
#   'aliases': ['Young Lord Hunter'],
#   'books': [3, 4, 5],
#   'url': 'Gilwood_Hunter'},
#  {'short_name': 'Kyle',
#   'common_name': 'Kyle',
#   'fullname': None,
#   'aliases': ['Cat of Misty Moor', 'Kyle the Cat'],
#   'books': [],
#   'url': 'Kyle'},
#  {'short_name': 'Frenya',
#   'common_name': 'Frenya',
#   'fullname': None,
#   'aliases': None,
#   'books': [5],
#   'url': 'Frenya'},
#  {'short_name': 'Mylenda Caron',
#   'common_name': 'Mylenda Caron',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4],
#   'url': 'Mylenda_Caron'},
#  {'short_name': 'Pate',
#   'common_name': 'Pate (Standfast)',
#   'fullname': None,
#   'aliases': None,
#   'books': [],
#   'url': 'Pate_(Standfast)'},
#  {'short_name': 'Aeron Greyjoy',
#   'common_name': 'Aeron Greyjoy',
#   'fullname': None,
#   'aliases': ['The Damphair', 'Aeron Damphair'],
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Aeron_Greyjoy'},
#  {'short_name': 'Easy',
#   'common_name': 'Easy',
#   'fullname': None,
#   'aliases': None,
#   'books': [3],
#   'url': 'Easy'},
#  {'short_name': 'Elwood Meadows',
#   'common_name': 'Elwood Meadows',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4, 5],
#   'url': 'Elwood_Meadows'},
#  {'short_name': 'Benedict',
#   'common_name': 'Benedict',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Benedict'},
#  {'short_name': 'Ebben',
#   'common_name': 'Ebben',
#   'fullname': None,
#   'aliases': ['Eggen'],
#   'books': [2, 3, 4, 5],
#   'url': 'Ebben'},
#  {'short_name': 'Garth Greyfeather',
#   'common_name': 'Garth Greyfeather',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4, 5],
#   'url': 'Garth_Greyfeather'},
#  {'short_name': 'Coratt',
#   'common_name': 'Coratt',
#   'fullname': None,
#   'aliases': None,
#   'books': [1],
#   'url': 'Coratt'},
#  {'short_name': 'Missandei',
#   'common_name': 'Missandei',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4, 5],
#   'url': 'Missandei'},
#  {'short_name': 'Moon Boy',
#   'common_name': 'Moon Boy',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Moon_Boy'},
#  {'short_name': 'Archibald Yronwood',
#   'common_name': 'Archibald Yronwood',
#   'fullname': None,
#   'aliases': ['the big man', 'Arch', 'Greenguts'],
#   'books': [4, 5],
#   'url': 'Archibald_Yronwood'},
#  {'short_name': 'Rupert Crabb',
#   'common_name': 'Rupert Crabb',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Rupert_Crabb'},
#  {'short_name': 'Grenn',
#   'common_name': 'Grenn',
#   'fullname': None,
#   'aliases': ['Aurochs'],
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Grenn'},
#  {'short_name': 'Morra',
#   'common_name': 'Morra',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Morra'},
#  {'short_name': 'Ronnet Connington',
#   'common_name': 'Ronnet Connington',
#   'fullname': None,
#   'aliases': ['Red Ronnet'],
#   'books': [2, 3, 4, 5],
#   'url': 'Ronnet_Connington'},
#  {'short_name': 'Ormund Wylde',
#   'common_name': 'Ormund Wylde',
#   'fullname': None,
#   'aliases': None,
#   'books': [5],
#   'url': 'Ormund_Wylde'},
#  {'short_name': 'Rupert Brax',
#   'common_name': 'Rupert Brax',
#   'fullname': None,
#   'aliases': ['Rubert Brax'],
#   'books': [2, 3],
#   'url': 'Rupert_Brax'},
#  {'short_name': 'Aglantine',
#   'common_name': 'Aglantine',
#   'fullname': None,
#   'aliases': None,
#   'books': [4, 5],
#   'url': 'Aglantine'},
#  {'short_name': 'Aemond Targaryen',
#   'common_name': 'Aemond Targaryen',
#   'fullname': None,
#   'aliases': ['Aemond One-Eye Aemond the Kinslayer'],
#   'books': [5],
#   'url': 'Aemond_Targaryen'},
#  {'short_name': 'Balon Botley',
#   'common_name': 'Balon Botley',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Balon_Botley'},
#  {'short_name': 'Cregan Karstark',
#   'common_name': 'Cregan Karstark',
#   'fullname': None,
#   'aliases': None,
#   'books': [5],
#   'url': 'Cregan_Karstark'},
#  {'short_name': 'Arrec Durrandon',
#   'common_name': 'Arrec Durrandon',
#   'fullname': 'Arrec Durrandon',
#   'aliases': None,
#   'books': None,
#   'url': 'Arrec_Durrandon'},
#  {'short_name': 'Leo Lefford',
#   'common_name': 'Leo Lefford',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3],
#   'url': 'Leo_Lefford'},
#  {'short_name': 'Artos Stark',
#   'common_name': 'Artos Stark',
#   'fullname': None,
#   'aliases': ['Artos the Implacable'],
#   'books': [2, 5],
#   'url': 'Artos_Stark'},
#  {'short_name': 'Addam Frey',
#   'common_name': 'Addam Frey',
#   'fullname': None,
#   'aliases': None,
#   'books': [],
#   'url': 'Addam_Frey'},
#  {'short_name': 'Garth of Oldtown',
#   'common_name': 'Garth of Oldtown',
#   'fullname': None,
#   'aliases': None,
#   'books': [3],
#   'url': 'Garth_of_Oldtown'},
#  {'short_name': 'Mudge',
#   'common_name': 'Mudge (brotherhood)',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4],
#   'url': 'Mudge_(brotherhood)'},
#  {'short_name': 'Old Grey Gull',
#   'common_name': 'Old Grey Gull',
#   'fullname': None,
#   'aliases': None,
#   'books': [4, 5],
#   'url': 'Old_Grey_Gull'},
#  {'short_name': 'Nysterica',
#   'common_name': 'Nysterica',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4, 5],
#   'url': 'Nysterica'},
#  {'short_name': 'Ferny',
#   'common_name': 'Ferny',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4],
#   'url': 'Ferny'},
#  {'short_name': 'Wex Pyke',
#   'common_name': 'Wex Pyke',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4, 5],
#   'url': 'Wex_Pyke'},
#  {'short_name': 'Lyn Corbray',
#   'common_name': 'Lyn Corbray',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Lyn_Corbray'},
#  {'short_name': 'Gwynesse Harlaw',
#   'common_name': 'Gwynesse Harlaw',
#   'fullname': None,
#   'aliases': None,
#   'books': [4, 5],
#   'url': 'Gwynesse_Harlaw'},
#  {'short_name': 'Gerrick',
#   'common_name': 'Gerrick Kingsblood',
#   'fullname': None,
#   'aliases': ['Gerrick Kingsblood'],
#   'books': [5],
#   'url': 'Gerrick_Kingsblood'},
#  {'short_name': 'Eyron Stark',
#   'common_name': 'Eyron Stark',
#   'fullname': None,
#   'aliases': None,
#   'books': [2],
#   'url': 'Eyron_Stark'},
#  {'short_name': 'Theodore Tyrell',
#   'common_name': 'Theodore Tyrell',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4],
#   'url': 'Theodore_Tyrell'},
#  {'short_name': 'Bessa',
#   'common_name': 'Bessa (Winterfell)',
#   'fullname': None,
#   'aliases': None,
#   'books': [1],
#   'url': 'Bessa_(Winterfell)'},
#  {'short_name': 'Donnel Hill',
#   'common_name': 'Donnel Hill',
#   'fullname': None,
#   'aliases': ['Sweet Donnel Hill'],
#   'books': [3, 4, 5],
#   'url': 'Donnel_Hill'},
#  {'short_name': 'Melwyn Sarsfield',
#   'common_name': 'Melwyn Sarsfield',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4],
#   'url': 'Melwyn_Sarsfield'},
#  {'short_name': 'Lynesse Hightower',
#   'common_name': 'Lynesse Hightower',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4, 5],
#   'url': 'Lynesse_Hightower'},
#  {'short_name': 'Lucos',
#   'common_name': 'Lucos',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Lucos'},
#  {'short_name': 'Rolland Uffering',
#   'common_name': 'Rolland Uffering',
#   'fullname': None,
#   'aliases': None,
#   'books': [],
#   'url': 'Rolland_Uffering'},
#  {'short_name': 'Medgar Tully',
#   'common_name': 'Medgar Tully',
#   'fullname': None,
#   'aliases': None,
#   'books': [],
#   'url': 'Medgar_Tully'},
#  {'short_name': 'Garrett Flowers',
#   'common_name': 'Garrett Flowers',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Garrett_Flowers'},
#  {'short_name': 'Jonothor Darry',
#   'common_name': 'Jonothor Darry',
#   'fullname': None,
#   'aliases': ['Jon Darry'],
#   'books': [3, 4],
#   'url': 'Jonothor_Darry'},
#  {'short_name': 'Mark Ryswell',
#   'common_name': 'Mark Ryswell',
#   'fullname': None,
#   'aliases': None,
#   'books': [1],
#   'url': 'Mark_Ryswell'},
#  {'short_name': 'Robar Royce',
#   'common_name': 'Robar Royce',
#   'fullname': None,
#   'aliases': ['Robar the Red'],
#   'books': [1, 2, 3, 4],
#   'url': 'Robar_Royce'},
#  {'short_name': 'Oswyn',
#   'common_name': 'Oswyn',
#   'fullname': None,
#   'aliases': ['Oswyn Longneck the Thrice-Hanged'],
#   'books': [3],
#   'url': 'Oswyn'},
#  {'short_name': 'Raymar Royce',
#   'common_name': 'Raymar Royce',
#   'fullname': None,
#   'aliases': None,
#   'books': [3],
#   'url': 'Raymar_Royce'},
#  {'short_name': 'Roslin Frey',
#   'common_name': 'Roslin Frey',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4, 5],
#   'url': 'Roslin_Frey'},
#  {'short_name': None,
#   'common_name': 'Dance of the Dragons',
#   'fullname': None,
#   'aliases': None,
#   'books': None,
#   'url': 'Dance_of_the_Dragons'},
#  {'short_name': 'Marq Rankenfell',
#   'common_name': 'Marq Rankenfell',
#   'fullname': None,
#   'aliases': ['Mad Marq Rankenfell'],
#   'books': [3],
#   'url': 'Marq_Rankenfell'},
#  {'short_name': 'Boremund Harlaw',
#   'common_name': 'Boremund Harlaw',
#   'fullname': None,
#   'aliases': ['Boremund the Blue'],
#   'books': [4, 5],
#   'url': 'Boremund_Harlaw'},
#  {'short_name': 'Willas Tyrell',
#   'common_name': 'Willas Tyrell',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Willas_Tyrell'},
#  {'short_name': 'Willam',
#   'common_name': 'Willam',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Willam'},
#  {'short_name': 'Wilbert',
#   'common_name': 'Wilbert',
#   'fullname': None,
#   'aliases': None,
#   'books': [3],
#   'url': 'Wilbert'},
#  {'short_name': 'Armond Caswell',
#   'common_name': 'Armond Caswell',
#   'fullname': None,
#   'aliases': None,
#   'books': [],
#   'url': 'Armond_Caswell'},
#  {'short_name': None,
#   'common_name': 'Seven Kingdoms',
#   'fullname': None,
#   'aliases': None,
#   'books': None,
#   'url': 'Seven_Kingdoms'},
#  {'short_name': 'Beron Blacktyde',
#   'common_name': 'Beron Blacktyde',
#   'fullname': None,
#   'aliases': ['Blind Beron Blacktyde'],
#   'books': [4, 5],
#   'url': 'Beron_Blacktyde'},
#  {'short_name': 'Ysilla Royce',
#   'common_name': 'Ysilla Royce',
#   'fullname': None,
#   'aliases': None,
#   'books': [4, 5],
#   'url': 'Ysilla_Royce'},
#  {'short_name': None,
#   'common_name': 'Brave Companions',
#   'fullname': None,
#   'aliases': None,
#   'books': None,
#   'url': 'Brave_Companions'},
#  {'short_name': 'Clement Piper',
#   'common_name': 'Clement Piper',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 3, 4, 5],
#   'url': 'Clement_Piper'},
#  {'short_name': 'Jhogo',
#   'common_name': 'Jhogo',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Jhogo'},
#  {'short_name': 'Martyn Lannister',
#   'common_name': 'Martyn Lannister',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Martyn_Lannister'},
#  {'short_name': 'Spotted Pate',
#   'common_name': 'Spotted Pate of Maidenpool',
#   'fullname': None,
#   'aliases': ['Spotted Pate of Maidenpool'],
#   'books': [3],
#   'url': 'Spotted_Pate_of_Maidenpool'},
#  {'short_name': 'Janei Lannister',
#   'common_name': 'Janei Lannister',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Janei_Lannister'},
#  {'short_name': 'Melessa Florent',
#   'common_name': 'Melessa Florent',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4],
#   'url': 'Melessa_Florent'},
#  {'short_name': 'Hot Pie',
#   'common_name': 'Hot Pie',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4],
#   'url': 'Hot_Pie'},
#  {'short_name': 'Urrathon',
#   'common_name': 'Urrathon Night-Walker',
#   'fullname': None,
#   'aliases': ['Urrathon Night-Walker'],
#   'books': [2],
#   'url': 'Urrathon_Night-Walker'},
#  {'short_name': 'Eden Risley',
#   'common_name': 'Eden Risley',
#   'fullname': None,
#   'aliases': None,
#   'books': [],
#   'url': 'Eden_Risley'},
#  {'short_name': 'Cedric Payne',
#   'common_name': 'Cedric Payne',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Cedric_Payne'},
#  {'short_name': 'Edwyn Frey',
#   'common_name': 'Edwyn Frey',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4],
#   'url': 'Edwyn_Frey'},
#  {'short_name': 'Wendell Webber',
#   'common_name': 'Wendell Webber',
#   'fullname': None,
#   'aliases': None,
#   'books': [],
#   'url': 'Wendell_Webber'},
#  {'short_name': 'Tristan Ryger',
#   'common_name': 'Tristan Ryger',
#   'fullname': None,
#   'aliases': None,
#   'books': [3],
#   'url': 'Tristan_Ryger'},
#  {'short_name': 'Palla',
#   'common_name': 'Palla',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 4],
#   'url': 'Palla'},
#  {'short_name': 'Gran Goodbrother',
#   'common_name': 'Gran Goodbrother',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Gran_Goodbrother'},
#  {'short_name': 'Mikken',
#   'common_name': 'Mikken',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Mikken'},
#  {'short_name': 'Jeren',
#   'common_name': 'Jeren',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Jeren'},
#  {'short_name': 'Lanna',
#   'common_name': 'Lanna (Happy Port)',
#   'fullname': None,
#   'aliases': None,
#   'books': [4, 5],
#   'url': 'Lanna_(Happy_Port)'},
#  {'short_name': 'Jeyne Rivers',
#   'common_name': 'Jeyne Rivers',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4, 5],
#   'url': 'Jeyne_Rivers'},
#  {'short_name': 'Bryen',
#   'common_name': 'Bryen',
#   'fullname': None,
#   'aliases': None,
#   'books': [3],
#   'url': 'Bryen'},
#  {'short_name': 'Praed',
#   'common_name': 'Praed',
#   'fullname': None,
#   'aliases': None,
#   'books': [2],
#   'url': 'Praed'},
#  {'short_name': 'Jon Pox',
#   'common_name': 'Jon Pox',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Jon_Pox'},
#  {'short_name': None,
#   'common_name': 'Merling Queen',
#   'fullname': None,
#   'aliases': ['The Merling Queen'],
#   'books': [],
#   'url': 'Merling_Queen'},
#  {'short_name': 'Maegor I',
#   'common_name': 'Maegor I Targaryen',
#   'fullname': 'Maegor Targaryen the First of His Name',
#   'aliases': ['Maegor the Cruel', 'The Prince of Dragonstone'],
#   'books': None,
#   'url': 'Maegor_I_Targaryen'},
#  {'short_name': 'Maddy',
#   'common_name': 'Maddy',
#   'fullname': None,
#   'aliases': None,
#   'books': [4, 5],
#   'url': 'Maddy'},
#  {'short_name': 'Elyas Willum',
#   'common_name': 'Elyas Willum',
#   'fullname': None,
#   'aliases': None,
#   'books': [2],
#   'url': 'Elyas_Willum'},
#  {'short_name': 'Ulrick Dayne',
#   'common_name': 'Ulrick Dayne',
#   'fullname': None,
#   'aliases': None,
#   'books': [],
#   'url': 'Ulrick_Dayne'},
#  {'short_name': 'Kedry',
#   'common_name': 'Kedry',
#   'fullname': None,
#   'aliases': None,
#   'books': [4, 5],
#   'url': 'Kedry'},
#  {'short_name': 'Edwyle Stark',
#   'common_name': 'Edwyle Stark',
#   'fullname': None,
#   'aliases': None,
#   'books': [2],
#   'url': 'Edwyle_Stark'},
#  {'short_name': 'Rafe',
#   'common_name': 'Rafe',
#   'fullname': None,
#   'aliases': None,
#   'books': [],
#   'url': 'Rafe'},
#  {'short_name': 'Layna',
#   'common_name': 'Layna',
#   'fullname': None,
#   'aliases': None,
#   'books': [2],
#   'url': 'Layna'},
#  {'short_name': 'Ned Woods',
#   'common_name': 'Ned Woods',
#   'fullname': None,
#   'aliases': ['Noseless Ned'],
#   'books': [5],
#   'url': 'Ned_Woods'},
#  {'short_name': 'Karl',
#   'common_name': 'Clubfoot Karl',
#   'fullname': None,
#   'aliases': ['Clubfoot Karl'],
#   'books': [3, 4, 5],
#   'url': 'Clubfoot_Karl'},
#  {'short_name': 'Symon Hollard',
#   'common_name': 'Symon Hollard',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Symon_Hollard'},
#  {'short_name': 'Cafferen',
#   'common_name': 'Lord Cafferen',
#   'fullname': None,
#   'aliases': None,
#   'books': [3],
#   'url': 'Lord_Cafferen'},
#  {'short_name': 'Alyn Cockshaw',
#   'common_name': 'Alyn Cockshaw',
#   'fullname': None,
#   'aliases': None,
#   'books': [],
#   'url': 'Alyn_Cockshaw'},
#  {'short_name': None,
#   'common_name': 'House Tully',
#   'fullname': None,
#   'aliases': None,
#   'books': None,
#   'url': 'House_Tully'},
#  {'short_name': 'Tyene Sand',
#   'common_name': 'Tyene Sand',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4, 5],
#   'url': 'Tyene_Sand'},
#  {'short_name': 'Bharbo',
#   'common_name': 'Bharbo',
#   'fullname': None,
#   'aliases': None,
#   'books': [1],
#   'url': 'Bharbo'},
#  {'short_name': 'Damon Vypren',
#   'common_name': 'Damon Vypren',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4],
#   'url': 'Damon_Vypren'},
#  {'short_name': 'Watty',
#   'common_name': 'Watty',
#   'fullname': None,
#   'aliases': ['Watty the Miller'],
#   'books': [3, 4],
#   'url': 'Watty'},
#  {'short_name': 'Ardrian Celtigar',
#   'common_name': 'Ardrian Celtigar',
#   'fullname': None,
#   'aliases': ['the Red Crab'],
#   'books': [2, 3],
#   'url': 'Ardrian_Celtigar'},
#  {'short_name': 'Victor Tyrell',
#   'common_name': 'Victor Tyrell',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4],
#   'url': 'Victor_Tyrell'},
#  {'short_name': 'Dyah',
#   'common_name': 'Dyah',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4],
#   'url': 'Dyah'},
#  {'short_name': 'Merrell Florent',
#   'common_name': 'Merrell Florent',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4],
#   'url': 'Merrell_Florent'},
#  {'short_name': 'Harmen Uller',
#   'common_name': 'Harmen Uller',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4, 5],
#   'url': 'Harmen_Uller'},
#  {'short_name': 'Puckens',
#   'common_name': 'Puckens',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Puckens'},
#  {'short_name': 'Maelor Targaryen',
#   'common_name': 'Maelor Targaryen',
#   'fullname': None,
#   'aliases': None,
#   'books': [],
#   'url': 'Maelor_Targaryen'},
#  {'short_name': 'Cheyk',
#   'common_name': 'Cheyk',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 4, 5],
#   'url': 'Cheyk'},
#  {'short_name': 'Grisella',
#   'common_name': 'Grisella',
#   'fullname': None,
#   'aliases': None,
#   'books': [5],
#   'url': 'Grisella'},
#  {'short_name': 'Temmo',
#   'common_name': 'Temmo',
#   'fullname': None,
#   'aliases': None,
#   'books': [3],
#   'url': 'Temmo'},
#  {'short_name': 'Barthogan Stark',
#   'common_name': 'Barthogan Stark',
#   'fullname': None,
#   'aliases': ['Barth Blacksword'],
#   'books': [2],
#   'url': 'Barthogan_Stark'},
#  {'short_name': 'Preston Greenfield',
#   'common_name': 'Preston Greenfield',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3, 4],
#   'url': 'Preston_Greenfield'},
#  {'short_name': 'Ormond Yronwood',
#   'common_name': 'Ormond Yronwood',
#   'fullname': None,
#   'aliases': None,
#   'books': [4, 5],
#   'url': 'Ormond_Yronwood'},
#  {'short_name': 'Steffarion Sparr',
#   'common_name': 'Steffarion Sparr',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Steffarion_Sparr'},
#  {'short_name': 'Agrivane',
#   'common_name': 'Agrivane',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Agrivane'},
#  {'short_name': 'Loras Tyrell',
#   'common_name': 'Loras Tyrell',
#   'fullname': None,
#   'aliases': ['The Knight of Flowers',
#    "Knight o' Pansies",
#    'Ser Daisy',
#    "Renly's little rose"],
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Loras_Tyrell'},
#  {'short_name': 'Quentyn Qorgyle',
#   'common_name': 'Quentyn Qorgyle',
#   'fullname': None,
#   'aliases': None,
#   'books': [4, 5],
#   'url': 'Quentyn_Qorgyle'},
#  {'short_name': 'Emberlei Frey',
#   'common_name': 'Emberlei Frey',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4],
#   'url': 'Emberlei_Frey'},
#  {'short_name': 'Sigfryd Harlaw',
#   'common_name': 'Sigfryd Harlaw',
#   'fullname': None,
#   'aliases': ['Sigfryd Silverhair'],
#   'books': [4, 5],
#   'url': 'Sigfryd_Harlaw'},
#  {'short_name': 'Owen Norrey',
#   'common_name': 'Owen Norrey',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4],
#   'url': 'Owen_Norrey'},
#  {'short_name': 'Wun Weg Wun Dar Wun',
#   'common_name': 'Wun Weg Wun Dar Wun',
#   'fullname': None,
#   'aliases': ['Wun Wun'],
#   'books': [5],
#   'url': 'Wun_Weg_Wun_Dar_Wun'},
#  {'short_name': 'Rolland Longthorpe',
#   'common_name': 'Rolland Longthorpe',
#   'fullname': None,
#   'aliases': None,
#   'books': [4, 5],
#   'url': 'Rolland_Longthorpe'},
#  {'short_name': 'Joanna Swyft',
#   'common_name': 'Joanna Swyft',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4],
#   'url': 'Joanna_Swyft'},
#  {'short_name': 'Jurne',
#   'common_name': 'Jurne',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4],
#   'url': 'Jurne'},
#  {'short_name': None,
#   'common_name': 'Porridge',
#   'fullname': None,
#   'aliases': ['Porridge'],
#   'books': [3],
#   'url': 'Porridge'},
#  {'short_name': 'Yoren',
#   'common_name': 'Yoren',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3, 4],
#   'url': 'Yoren'},
#  {'short_name': 'Osha',
#   'common_name': 'Osha',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Osha'},
# ...
#  {'short_name': 'Cedrik Storm',
#   'common_name': 'Cedrik Storm',
#   'fullname': None,
#   'aliases': ['The Bastard of Bronzegate'],
#   'books': [3],
#   'url': 'Cedrik_Storm'},
#  {'short_name': 'Perwyn Frey',
#   'common_name': 'Perwyn Frey',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Perwyn_Frey'},
#  {'short_name': 'Annara Farring',
#   'common_name': 'Annara Farring',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4, 5],
#   'url': 'Annara_Farring'},
#  {'short_name': 'Vardis Egen',
#   'common_name': 'Vardis Egen',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3],
#   'url': 'Vardis_Egen'},
#  {'short_name': 'Bennarion Botley',
#   'common_name': 'Bennarion Botley',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Bennarion_Botley'},
#  {'short_name': 'Osmynd',
#   'common_name': 'Osmynd',
#   'fullname': None,
#   'aliases': None,
#   'books': [2],
#   'url': 'Osmynd'},
#  {'short_name': 'Jon Redfort',
#   'common_name': 'Jon Redfort',
#   'fullname': None,
#   'aliases': None,
#   'books': [4, 5],
#   'url': 'Jon_Redfort'},
#  {'short_name': 'Dirk',
#   'common_name': 'Dirk',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4, 5],
#   'url': 'Dirk'},
#  {'short_name': 'Eustace Brune',
#   'common_name': 'Eustace Brune',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Eustace_Brune'},
#  {'short_name': 'Jojen Reed',
#   'common_name': 'Jojen Reed',
#   'fullname': None,
#   'aliases': ['Little Grandfather'],
#   'books': [2, 3, 4, 5],
#   'url': 'Jojen_Reed'},
#  {'short_name': 'Leobald Tallhart',
#   'common_name': 'Leobald Tallhart',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4, 5],
#   'url': 'Leobald_Tallhart'},
#  {'short_name': 'Corliss Penny',
#   'common_name': 'Corliss Penny',
#   'fullname': None,
#   'aliases': None,
#   'books': [4, 5],
#   'url': 'Corliss_Penny'},
#  {'short_name': 'Marsella Waynwood',
#   'common_name': 'Marsella Waynwood',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4],
#   'url': 'Marsella_Waynwood'},
#  {'short_name': 'Gage',
#   'common_name': 'Gage',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3],
#   'url': 'Gage'},
#  {'short_name': 'Orphan Oss',
#   'common_name': 'Orphan Oss',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4, 5],
#   'url': 'Orphan_Oss'},
#  {'short_name': None,
#   'common_name': 'Karhold',
#   'fullname': None,
#   'aliases': None,
#   'books': None,
#   'url': 'Karhold'},
#  {'short_name': 'Young Henly',
#   'common_name': 'Young Henly',
#   'fullname': None,
#   'aliases': None,
#   'books': [3],
#   'url': 'Young_Henly'},
#  {'short_name': 'Alyn Connington',
#   'common_name': 'Alyn Connington',
#   'fullname': None,
#   'aliases': ['The Pale Griffin'],
#   'books': [3, 4],
#   'url': 'Alyn_Connington'},
#  {'short_name': 'Alysanne Targaryen',
#   'common_name': 'Alysanne Targaryen',
#   'fullname': 'Alysanne of House Targaryen',
#   'aliases': ['Good Queen Alysanne'],
#   'books': None,
#   'url': 'Alysanne_Targaryen'},
#  {'short_name': 'Delena Florent',
#   'common_name': 'Delena Florent',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4, 5],
#   'url': 'Delena_Florent'},
#  {'short_name': 'William Mooton',
#   'common_name': 'William Mooton',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4, 5],
#   'url': 'William_Mooton'},
#  {'short_name': 'Harys Swyft',
#   'common_name': 'Harys Swyft',
#   'fullname': None,
#   'aliases': ['The knight of the yellow chicken'],
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Harys_Swyft'},
#  {'short_name': 'Lew',
#   'common_name': 'Long Lew',
#   'fullname': None,
#   'aliases': ['Long Lew'],
#   'books': [2, 3, 4, 5],
#   'url': 'Long_Lew'},
#  {'short_name': 'Hallyne',
#   'common_name': 'Hallyne',
#   'fullname': None,
#   'aliases': ['Hallyne the Pryomancer'],
#   'books': [2, 3, 4],
#   'url': 'Hallyne'},
#  {'short_name': 'Branston Cuy',
#   'common_name': 'Branston Cuy',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Branston_Cuy'},
#  {'short_name': 'Maron Greyjoy',
#   'common_name': 'Maron Greyjoy',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Maron_Greyjoy'},
#  {'short_name': 'Urswyck',
#   'common_name': 'Urswyck',
#   'fullname': None,
#   'aliases': ['Urswyck the Faithful', 'Faithful Urswyck'],
#   'books': [2, 3, 4],
#   'url': 'Urswyck'},
#  {'short_name': 'Mago',
#   'common_name': 'Mago',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 3, 4, 5],
#   'url': 'Mago'},
#  {'short_name': 'Deziel Dalt',
#   'common_name': 'Deziel Dalt',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4, 5],
#   'url': 'Deziel_Dalt'},
#  {'short_name': None,
#   'common_name': 'House Baratheon',
#   'fullname': None,
#   'aliases': None,
#   'books': None,
#   'url': 'House_Baratheon'},
#  {'short_name': 'Stonehand',
#   'common_name': 'Stonehand',
#   'fullname': None,
#   'aliases': None,
#   'books': [4, 5],
#   'url': 'Stonehand'},
#  {'short_name': 'Shyra',
#   'common_name': 'Shyra',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 4],
#   'url': 'Shyra'},
#  {'short_name': 'Harma',
#   'common_name': 'Harma',
#   'fullname': None,
#   'aliases': ['Harma the Dogshead', 'Harma Dogshead'],
#   'books': [2, 3, 5],
#   'url': 'Harma'},
#  {'short_name': 'Jasper Arryn',
#   'common_name': 'Jasper Arryn',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Jasper_Arryn'},
#  {'short_name': 'Tarber',
#   'common_name': 'Tarber',
#   'fullname': None,
#   'aliases': None,
#   'books': [2],
#   'url': 'Tarber'},
#  {'short_name': 'Ulmer',
#   'common_name': 'Ulmer',
#   'fullname': None,
#   'aliases': ['Ulmer of the Kingswood'],
#   'books': [3, 4, 5],
#   'url': 'Ulmer'},
#  {'short_name': 'Old Henly',
#   'common_name': 'Old Henly',
#   'fullname': None,
#   'aliases': None,
#   'books': [3],
#   'url': 'Old_Henly'},
#  {'short_name': 'Craster',
#   'common_name': 'Craster',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4, 5],
#   'url': 'Craster'},
#  {'short_name': 'Samwell Tarly',
#   'common_name': 'Samwell Tarly',
#   'fullname': None,
#   'aliases': ['Sam',
#    'Ser Piggy',
#    'Lady Piggy',
#    'Lord of Ham',
#    'Sam the Slayer',
#    'Black Sam'],
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Samwell_Tarly'},
#  {'short_name': 'Marwyn',
#   'common_name': 'Marwyn',
#   'fullname': None,
#   'aliases': ['Marwyn the Mage', 'The Mage', 'The mastiff'],
#   'books': [1, 3, 4],
#   'url': 'Marwyn'},
#  {'short_name': 'Ragnor Pyke',
#   'common_name': 'Ragnor Pyke',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Ragnor_Pyke'},
#  {'short_name': 'Aerys II',
#   'common_name': 'Aerys II Targaryen',
#   'fullname': 'Aerys Targaryen the Second of His Name',
#   'aliases': ['The Mad King', 'King Scab'],
#   'books': None,
#   'url': 'Aerys_II_Targaryen'},
#  {'short_name': 'Androw Ashford',
#   'common_name': 'Androw Ashford',
#   'fullname': None,
#   'aliases': None,
#   'books': [],
#   'url': 'Androw_Ashford'},
#  {'short_name': 'Hother Umber',
#   'common_name': 'Hother Umber',
#   'fullname': None,
#   'aliases': ['Hother Whoresbane', 'Whoresbane Umber'],
#   'books': [2, 3, 4, 5],
#   'url': 'Hother_Umber'},
#  {'short_name': 'Willem Darry',
#   'common_name': 'Willem Darry',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3, 5],
#   'url': 'Willem_Darry'},
#  {'short_name': 'Bellena Hawick',
#   'common_name': 'Bellena Hawick',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4],
#   'url': 'Bellena_Hawick'},
#  {'short_name': 'Harmune',
#   'common_name': 'Harmune',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4, 5],
#   'url': 'Harmune'},
#  {'short_name': 'Simon Leygood',
#   'common_name': 'Simon Leygood',
#   'fullname': None,
#   'aliases': None,
#   'books': [],
#   'url': 'Simon_Leygood'},
#  {'short_name': 'Jon Brax',
#   'common_name': 'Jon Brax',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4],
#   'url': 'Jon_Brax'},
#  {'short_name': 'Hayhead',
#   'common_name': 'Hayhead',
#   'fullname': None,
#   'aliases': None,
#   'books': [2],
#   'url': 'Hayhead'},
#  {'short_name': 'Axell Florent',
#   'common_name': 'Axell Florent',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4, 5],
#   'url': 'Axell_Florent'},
#  {'short_name': 'Harras Harlaw',
#   'common_name': 'Harras Harlaw',
#   'fullname': None,
#   'aliases': ['The Knight of Grey Garden'],
#   'books': [4, 5],
#   'url': 'Harras_Harlaw'},
#  {'short_name': 'Cutjack',
#   'common_name': 'Cutjack',
#   'fullname': None,
#   'aliases': None,
#   'books': [2],
#   'url': 'Cutjack'},
#  {'short_name': 'Morya Frey',
#   'common_name': 'Morya Frey',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4, 5],
#   'url': 'Morya_Frey'},
#  {'short_name': 'Tybolt Crakehall',
#   'common_name': 'Tybolt Crakehall',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4],
#   'url': 'Tybolt_Crakehall'},
#  {'short_name': 'Wenda',
#   'common_name': 'Wenda',
#   'fullname': None,
#   'aliases': ['Wenda the White Fawn'],
#   'books': [3, 4, 5],
#   'url': 'Wenda'},
#  {'short_name': 'Denyse Hightower',
#   'common_name': 'Denyse Hightower',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Denyse_Hightower'},
#  {'short_name': 'Marq Piper',
#   'common_name': 'Marq Piper',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Marq_Piper'},
#  {'short_name': 'Gunthor Hightower',
#   'common_name': 'Gunthor Hightower',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Gunthor_Hightower'},
#  {'short_name': 'Rolly Duckfield',
#   'common_name': 'Rolly Duckfield',
#   'fullname': None,
#   'aliases': ['Duck', 'Ser Duck'],
#   'books': [5],
#   'url': 'Rolly_Duckfield'},
#  {'short_name': 'Ryger Rivers',
#   'common_name': 'Ryger Rivers',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Ryger_Rivers'},
#  {'short_name': 'Harlon Botley',
#   'common_name': 'Harlon Botley',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Harlon_Botley'},
#  {'short_name': 'Rakharo',
#   'common_name': 'Rakharo',
#   'fullname': None,
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Rakharo'},
#  {'short_name': 'Lorren',
#   'common_name': 'Lorren',
#   'fullname': None,
#   'aliases': ['Black Lorren'],
#   'books': [2],
#   'url': 'Lorren'},
#  {'short_name': 'Meera Reed',
#   'common_name': 'Meera Reed',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4, 5],
#   'url': 'Meera_Reed'},
#  {'short_name': 'Ryn',
#   'common_name': 'Anvil Ryn',
#   'fullname': None,
#   'aliases': ['Anvyl Ryn'],
#   'books': [3],
#   'url': 'Anvil_Ryn'},
#  {'short_name': 'Lucan',
#   'common_name': 'Lucan',
#   'fullname': None,
#   'aliases': None,
#   'books': [2],
#   'url': 'Lucan'},
#  {'short_name': 'Jonos Frey',
#   'common_name': 'Jonos Frey',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4],
#   'url': 'Jonos_Frey'},
#  {'short_name': 'Catelyn Bracken',
#   'common_name': 'Catelyn Bracken',
#   'fullname': None,
#   'aliases': None,
#   'books': [5],
#   'url': 'Catelyn_Bracken'},
#  {'short_name': 'Rickard Wylde',
#   'common_name': 'Rickard Wylde',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4],
#   'url': 'Rickard_Wylde'},
#  {'short_name': 'Sawwood',
#   'common_name': 'Sawwood',
#   'fullname': None,
#   'aliases': None,
#   'books': [3],
#   'url': 'Sawwood'},
#  {'short_name': 'Harry Strickland',
#   'common_name': 'Harry Strickland',
#   'fullname': None,
#   'aliases': ['Homeless Harry Strickland'],
#   'books': [5],
#   'url': 'Harry_Strickland'},
#  {'short_name': 'Garlan Tyrell',
#   'common_name': 'Garlan Tyrell',
#   'fullname': None,
#   'aliases': ['Garlan the Gallant',
#    "Renly's ghost",
#    'Lord Renly',
#    "Lord Renly's shade"],
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Garlan_Tyrell'},
#  {'short_name': 'Will',
#   'common_name': 'Will (squire)',
#   'fullname': None,
#   'aliases': None,
#   'books': [],
#   'url': 'Will_(squire)'},
#  {'short_name': 'Walder Frey',
#   'common_name': 'Walder Frey (son of Emmon)',
#   'fullname': None,
#   'aliases': ['Red Walder'],
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Walder_Frey_(son_of_Emmon)'},
#  {'short_name': 'Hairy Hal',
#   'common_name': 'Hairy Hal',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4, 5],
#   'url': 'Hairy_Hal'},
#  {'short_name': 'Collio Quaynis',
#   'common_name': 'Collio Quaynis',
#   'fullname': None,
#   'aliases': None,
#   'books': [3],
#   'url': 'Collio_Quaynis'},
#  {'short_name': 'Gyles Farwynd',
#   'common_name': 'Gyles Farwynd',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Gyles_Farwynd'},
#  {'short_name': 'Ryella Royce',
#   'common_name': 'Ryella Royce',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4],
#   'url': 'Ryella_Royce'},
#  {'short_name': 'Damon Shett',
#   'common_name': 'Damon Shett',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Damon_Shett'},
#  {'short_name': 'Ironbelly',
#   'common_name': 'Ironbelly',
#   'fullname': None,
#   'aliases': ['Ironbelly'],
#   'books': [2, 3],
#   'url': 'Ironbelly'},
#  {'short_name': 'Stannis Baratheon',
#   'common_name': 'Stannis Baratheon',
#   'fullname': 'Stannis Baratheon the First of His Name',
#   'aliases': ['The King in the Narrow Sea',
#    'The King of the Painted Table',
#    'The dark lord',
#    'The King of Dragonstone',
#    'The King at the Wall',
#    'Azor Ahai reborn/come again'],
#   'books': None,
#   'url': 'Stannis_Baratheon'},
#  {'short_name': 'Guyard Morrigen',
#   'common_name': 'Guyard Morrigen',
#   'fullname': None,
#   'aliases': ['Guyard the Green'],
#   'books': [2, 5],
#   'url': 'Guyard_Morrigen'},
#  {'short_name': 'Quaithe',
#   'common_name': 'Quaithe',
#   'fullname': None,
#   'aliases': ['Quaithe of the Shadow'],
#   'books': [2, 3, 4, 5],
#   'url': 'Quaithe'},
#  {'short_name': 'Quincy Cox',
#   'common_name': 'Quincy Cox',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Quincy_Cox'},
#  {'short_name': 'Styr',
#   'common_name': 'Styr',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4, 5],
#   'url': 'Styr'},
#  {'short_name': 'Olymer Tyrell',
#   'common_name': 'Olymer Tyrell',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4],
#   'url': 'Olymer_Tyrell'},
#  {'short_name': 'Lancel V Lannister',
#   'common_name': 'Lancel V Lannister',
#   'fullname': 'Lancel of House Lannister, the Fifth of His Name',
#   'aliases': None,
#   'books': None,
#   'url': 'Lancel_V_Lannister'},
#  {'short_name': 'Martyn Mullendore',
#   'common_name': 'Martyn Mullendore',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Martyn_Mullendore'},
#  {'short_name': 'Pate',
#   'common_name': "Pate (Night's Watch)",
#   'fullname': None,
#   'aliases': ['Spotted Pate'],
#   'books': [1],
#   'url': 'Pate_(Night%27s_Watch)'},
#  {'short_name': 'Lucas Nayland',
#   'common_name': 'Lucas Nayland',
#   'fullname': None,
#   'aliases': None,
#   'books': [],
#   'url': 'Lucas_Nayland'},
#  {'short_name': 'Mengo',
#   'common_name': 'Moro (Century of Blood)',
#   'fullname': None,
#   'aliases': None,
#   'books': [],
#   'url': 'Moro_(Century_of_Blood)'},
#  {'short_name': 'Grazdan mo Ullhor',
#   'common_name': 'Grazdan mo Ullhor',
#   'fullname': None,
#   'aliases': None,
#   'books': [3],
#   'url': 'Grazdan_mo_Ullhor'},
#  {'short_name': 'Lyonel Strong',
#   'common_name': 'Lyonel Strong',
#   'fullname': None,
#   'aliases': None,
#   'books': [],
#   'url': 'Lyonel_Strong'},
#  {'short_name': 'Yohn Farwynd',
#   'common_name': 'Yohn Farwynd',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Yohn_Farwynd'},
#  {'short_name': 'Walder Frey',
#   'common_name': 'Walder Frey',
#   'fullname': None,
#   'aliases': ['The Late Lord Frey', 'Old Frey'],
#   'books': [1, 2, 3, 4, 5],
#   'url': 'Walder_Frey'},
#  {'short_name': 'Rhialta Vance',
#   'common_name': 'Rhialta Vance',
#   'fullname': None,
#   'aliases': None,
#   'books': [4],
#   'url': 'Rhialta_Vance'},
#  {'short_name': 'Tanton Fossoway',
#   'common_name': 'Tanton Fossoway',
#   'fullname': None,
#   'aliases': None,
#   'books': [2, 3, 4, 5],
#   'url': 'Tanton_Fossoway'},
#  {'short_name': 'Robyn Rhysling',
#   'common_name': 'Robyn Rhysling',
#   'fullname': None,
#   'aliases': None,
#   'books': [],
#   'url': 'Robyn_Rhysling'},
#  {'short_name': 'Larra Blackmont',
#   'common_name': 'Larra Blackmont',
#   'fullname': None,
#   'aliases': None,
#   'books': [3, 4, 5],
#   'url': 'Larra_Blackmont'},
#  {'short_name': 'Sylas',
#   'common_name': 'Sylas',
#   'fullname': None,
#   'aliases': ['Sylas Sourmouth'],
#   'books': [2],
#   'url': 'Sylas'},
#  ...]

# %%
with open('characters_links.pickle','rb') as fp:
    character_links = pickle.load(fp)
character_links
# Out:
# [{'Sumner_Crakehall': ['Sumner_Crakehall',
#    'Aerys_II_Targaryen',
#    'Jaime_Lannister',
#    'Merrett_Frey',
#    'Kingswood_Brotherhood',
#    'Wenda']},
#  {'Lamprey': ['Dragonstone', 'Davos_Seaworth']},
#  {'Rhaego': ['House_Targaryen',
#    'Daenerys_Targaryen',
#    'Drogo',
#    'Drogo',
#    'Mirri_Maz_Duur',
#    'Daenerys_Targaryen',
#    'Mirri_Maz_Duur',
#    'Mirri_Maz_Duur',
#    'Jorah_Mormont',
#    'Mirri_Maz_Duur',
#    'Daenerys_Targaryen',
#    'Aegon_V_Targaryen',
#    'Duncan_Targaryen',
#    'Jaehaerys_II_Targaryen',
#    'Rhaelle_Targaryen',
#    'Aerys_II_Targaryen',
#    'Rhaella_Targaryen',
#    'House_Baratheon',
#    'Rhaegar_Targaryen',
#    'Elia_Martell',
#    'Drogo',
#    'Daenerys_Targaryen',
#    'Hizdahr_zo_Loraq',
#    'Rhaenys_Targaryen_(daughter_of_Rhaegar)',
#    'Aegon_Targaryen_(son_of_Rhaegar)',
#    'Viserys_Targaryen']},
#  {'Jeyne_Waters': ['Alyn_Velaryon',
#    'Elaena_Targaryen',
#    'Alyn_Velaryon',
#    'Elaena_Targaryen',
#    'Jon_Waters',
#    'Daemon_Targaryen',
#    'Laena_Velaryon',
#    'Laenor_Velaryon',
#    'Rhaenyra_Targaryen',
#    'Daemon_Targaryen',
#    'Addam_Velaryon',
#    'Aegon_III_Targaryen',
#    'Rhaena_Targaryen_(daughter_of_Daemon)',
#    'Baela_Targaryen',
#    'Alyn_Velaryon',
#    'Elaena_Targaryen',
#    'Jon_Waters',
#    'Daemon_Targaryen',
#    'Rhea_Royce',
#    'Laena_Velaryon',
#    'Rhaenyra_Targaryen']},
#  {'Sybell_Spicer': ['Sybell_Spicer',
#    'Gawen_Westerling',
#    'Gawen_Westerling',
#    'Robb_Stark',
#    'Westerlands',
#    'Riverrun',
#    'Jeyne_Westerling',
#    'Eleyna_Westerling',
#    'Rollam_Westerling',
#    'Edmure_Tully',
#    'Jaime_Lannister',
#    'Casterly_Rock',
#    'Joy_Hill',
#    'Gerion_Lannister',
#    'Rolph_Spicer',
#    'Raynald_Westerling',
#    'Rolph_Spicer',
#    'Gawen_Westerling',
#    'Raynald_Westerling',
#    'Jeyne_Westerling',
#    'Robb_Stark',
#    'Eleyna_Westerling',
#    'Rollam_Westerling']},
#  {'Dennet': ['Brotherhood_without_banners',
#    'Brotherhood_without_banners',
#    'Sandor_Clegane',
#    'Beric_Dondarrion',
#    'Anguy',
#    'Kyle']},
#  {'Lord_Ashford': ['The_Hedge_Knight',
#    'Daeron_II_Targaryen',
#    'Androw_Ashford',
#    'Robert_Ashford',
#    'Tourney_at_Ashford_Meadow',
#    'Hand_of_the_King',
#    'Baelor_Targaryen_(son_of_Daeron_II)',
#    'The_Hedge_Knight']},
#  {'Selyse_Florent': ['Selyse_Florent',
#    'Stannis_Baratheon',
#    'Stannis_Baratheon',
#    'Dragonstone',
#    'R%27hllor',
#    'Melisandre',
#    'Stannis_Baratheon',
#    'Shireen_Baratheon',
#    'Delena_Florent',
#    'Edric_Storm',
#    'Shireen_Baratheon',
#    'Varys',
#    'Melisandre',
#    'R%27hllor',
#    'Axell_Florent',
#    'Joffrey_Baratheon',
#    'Shireen_Baratheon',
#    'Patchface',
#    'Storm%27s_End',
#    'Axell_Florent',
#    'Renly_Baratheon',
#    'Imry_Florent',
#    'Dragonstone',
#    'Alester_Florent',
#    'Hand_of_the_King',
#    'Edric_Storm',
#    'Davos_Seaworth',
#    'Night%27s_Watch',
#    'Eastwatch-by-the-Sea',
#    'Castle_Black',
#    'Eastwatch-by-the-Sea',
#    'Cotter_Pyke',
#    'Patchface',
#    'Jon_Snow',
#    'Gerrick_Kingsblood',
#    'Axell_Florent',
#    'Raymun_Redbeard',
#    'King-Beyond-the-Wall',
#    'Tormund',
#    'Val',
#    'Stannis_Baratheon',
#    'R%27hllor',
#    'Delena_Florent',
#    'Stannis_Baratheon',
#    'Edric_Storm',
#    'Jon_Snow',
#    'Jon_Snow',
#    'Melisandre',
#    'Seven_Kingdoms',
#    'R%27hllor',
#    'Cressen',
#    'Petyr_Baelish',
#    'Pycelle',
#    'Stannis_Baratheon',
#    'Melisandre',
#    'Jon_Snow',
#    'Val',
#    'Jon_Snow',
#    'Jon_Snow',
#    'Tormund',
#    'Jon_Snow',
#    'Alester_Florent',
#    'Melara_Crane',
#    'Axell_Florent',
#    'Ryam_Florent',
#    'Colin_Florent',
#    'Rylene_Florent',
#    'Rycherd_Crane',
#    'Randyll_Tarly',
#    'Melessa_Florent',
#    'Alekyne_Florent',
#    'Rhea_Florent',
#    'Leyton_Hightower',
#    'Stannis_Baratheon',
#    'Imry_Florent',
#    'Erren_Florent',
#    'Hosman_Norcross',
#    'Delena_Florent',
#    'Omer_Florent',
#    'Merrell_Florent',
#    'Samwell_Tarly',
#    'Talla_Tarly',
#    'Dickon_Tarly',
#    'Shireen_Baratheon',
#    'Alester_Norcross',
#    'Renly_Norcross',
#    'Edric_Storm',
#    'House_Targaryen',
#    'Visenya_Targaryen',
#    'Rhaenys_Targaryen',
#    'Jeyne_Westerling_(wife_of_Maegor_I)',
#    'Alysanne_Targaryen',
#    'Aemma_Arryn',
#    'Alicent_Hightower',
#    'Helaena_Targaryen',
#    'Jaehaera_Targaryen',
#    'Daena_Targaryen',
#    'Naerys_Targaryen',
#    'Aelinor_Penrose',
#    'Rhaella_Targaryen',
#    'Daemon_Targaryen',
#    'Drogo',
#    'Hizdahr_zo_Loraq',
#    'House_Baratheon',
#    'Cersei_Lannister',
#    'Margaery_Tyrell',
#    'Margaery_Tyrell',
#    'Alannys_Harlaw',
#    'House_Stark',
#    'Jeyne_Westerling']},
#  {'Humfrey_Beesbury': ['Humfrey_Beesbury',
#    'Knight',
#    'The_Hedge_Knight',
#    'Knight',
#    'Daeron_II_Targaryen',
#    'Humfrey_Hardyng',
#    'Tourney_at_Ashford_Meadow',
#    'Humfrey_Hardyng',
#    'Donnel_of_Duskendale',
#    'The_Hedge_Knight']},
#  {'Jayde': ['Jayde',
#    'King%27s_Landing',
#    'Anguy',
#    'King%27s_Landing',
#    'Alayaya',
#    'Dancy',
#    'Chataya']},
#  {'Robin_Hollard': ['Robin_Hollard',
#    'Aerys_II_Targaryen',
#    'Denys_Darklyn',
#    'Serala',
#    'Jon_Hollard',
#    'Steffon_Hollard',
#    'Symon_Hollard',
#    'Dontos_Hollard']},
#  {'Dunaver': ['Dunaver',
#    'Knight',
#    'House_Lannister',
#    'House_Lannister',
#    'Tywin_Lannister',
#    'Harrenhal']},
#  {'Esgred': ['Esgred',
#    'Sigrin',
#    'Lordsport',
#    'Theon_Greyjoy',
#    'Pyke',
#    'Asha_Greyjoy']},
#  {'Lewyn_Martell': ['Lewyn_Martell',
#    'Lewyn_Martell',
#    'Knight',
#    'House_Martell',
#    'Kingsguard',
#    'Knight',
#    'House_Martell',
#    'Aerys_II_Targaryen',
#    'Kingsguard',
#    'Doran_Martell',
#    'Kingsguard',
#    'Aerys_II_Targaryen',
#    'Elia_Martell',
#    'Rhaegar_Targaryen',
#    'Lyn_Corbray',
#    'Oberyn_Martell',
#    'Viserys_Targaryen',
#    'Jon_Arryn',
#    'Sunspear',
#    'Doran_Martell',
#    'Arianne_Martell',
#    'Barristan_Selmy',
#    'Gerold_Hightower',
#    'Barristan_Selmy',
#    'Arthur_Dayne',
#    'Oswell_Whent',
#    'Jonothor_Darry',
#    'Jaime_Lannister',
#    'Loras_Tyrell',
#    'Osmund_Kettleblack',
#    'Balon_Swann',
#    'Meryn_Trant',
#    'Boros_Blount',
#    'Knight',
#    'Arys_Oakheart',
#    'Arianne_Martell',
#    'Arianne_Martell',
#    'Arys_Oakheart',
#    'Doran_Martell',
#    'Mors_Martell_(brother_of_Doran)',
#    'Elia_Martell',
#    'Rhaegar_Targaryen',
#    'Oberyn_Martell',
#    'Ellaria_Sand',
#    'Arianne_Martell',
#    'Quentyn_Martell',
#    'Trystane_Martell',
#    'Rhaenys_Targaryen_(daughter_of_Rhaegar)',
#    'Aegon_Targaryen_(son_of_Rhaegar)',
#    'Obara_Sand',
#    'Tyene_Sand',
#    'Elia_Sand',
#    'Dorea_Sand',
#    'Nymeria_Sand',
#    'Sarella_Sand',
#    'Obella_Sand',
#    'Loreza_Sand',
#    'Kingsguard',
#    'Aerys_II_Targaryen',
#    'Gerold_Hightower',
#    'Arthur_Dayne',
#    'Oswell_Whent',
#    'Jonothor_Darry',
#    'Barristan_Selmy',
#    'Jaime_Lannister',
#    'Gwayne_Gaunt',
#    'Harlan_Grandison']},
#  {'Samwell_Spicer': ['Samwell_Spicer',
#    'Knight',
#    'Sybell_Spicer',
#    'Rolph_Spicer',
#    'Jaime_Lannister',
#    'Riverrun',
#    'Tywin_Lannister',
#    'Riverlands']},
#  {'Kella': ['Kella', 'Petyr_Baelish', 'Sansa_Stark']},
#  {'Gormon_Peake': ['Gormon_Peake',
#    'Daemon_II_Blackfyre',
#    'Daemon_I_Blackfyre',
#    'First_Blackfyre_Rebellion',
#    'Knight',
#    'Roger_of_Pennytree',
#    'Daeron_II_Targaryen',
#    'Aerys_I_Targaryen',
#    'Daemon_II_Blackfyre',
#    'Aegon_V_Targaryen',
#    'Tommard_Heddle',
#    'Glendon_Flowers',
#    'Brynden_Rivers',
#    'Hand_of_the_King',
#    'Citadel',
#    'Aegor_Rivers']},
#  {'Godry_Farring': ['Godry_Farring',
#    'Knight',
#    'Knight',
#    'Stannis_Baratheon',
#    'R%27hllor',
#    'Clayton_Suggs',
#    'Giants',
#    'Castle_Black',
#    'Stannis_Baratheon',
#    'Jon_Snow',
#    'Janos_Slynt',
#    'Melisandre',
#    'Mors_Umber',
#    'Val',
#    'Richard_Horpe',
#    'Justin_Massey',
#    'R%27hllor',
#    'Clayton_Suggs',
#    'Theon_Greyjoy',
#    'Jon_Snow',
#    'Giants',
#    'Mors_Umber',
#    'Jon_Snow',
#    'R%27hllor',
#    'Asha_Greyjoy']},
#  {'Wyl_(guard)': ['House_Stark',
#    'King%27s_Landing',
#    'House_Stark',
#    'Eddard_Stark',
#    'Hand_of_the_King',
#    'Jaime_Lannister']},
#  {'Ollo_Lophand': ['Night%27s_Watch',
#    'Tyrosh',
#    'Night%27s_Watch',
#    'Tyrosh',
#    'Knight',
#    'Chett',
#    'Castle_Black',
#    'Jeor_Mormont',
#    'Bran_Stark',
#    'Coldhands']},
#  {'Ferrego_Antaryon': ['Ferrego_Antaryon',
#    'Braavos',
#    'Braavos',
#    'Braavos',
#    'Qarro_Volentin',
#    'First_Sword_of_Braavos']},
#  {'Anders_Yronwood': ['Anders_Yronwood',
#    'Cletus_Yronwood',
#    'Quentyn_Martell',
#    'Arys_Oakheart',
#    'Myrcella_Baratheon',
#    'Arianne_Martell',
#    'Quentyn_Martell',
#    'Doran_Martell',
#    'Sunspear',
#    'Criston_Cole',
#    'Quentyn_Martell',
#    'Doran_Martell',
#    'Arianne_Martell',
#    'Arianne_Martell',
#    'Arys_Oakheart',
#    'Ormond_Yronwood',
#    'Ryon_Allyrion',
#    'Cletus_Yronwood',
#    'Archibald_Yronwood']},
#  {'Lomas_Estermont': ['Lomas_Estermont',
#    'Knight',
#    'Knight',
#    'Andrew_Estermont',
#    'Stannis_Baratheon',
#    'Storm%27s_End',
#    'Tommen_Baratheon',
#    'Stannis_Baratheon',
#    'Andrew_Estermont',
#    'Eldon_Estermont']},
#  {'Hoke': ['Hoke',
#    'House_Lannister',
#    'House_Lannister',
#    'Cersei_Lannister',
#    'Hand_of_the_King',
#    'Jaime_Lannister']},
#  {'Edwyd_Fossoway': ['Edwyd_Fossoway',
#    'Knight',
#    'House_Fossoway_of_Cider_Hall',
#    'Knight',
#    'House_Fossoway_of_Cider_Hall',
#    'Stannis_Baratheon',
#    'Lothor_Brune',
#    'Bryan_Fossoway']},
#  {'Leyla_Hightower': ['Jon_Cupps',
#    'Leyton_Hightower',
#    'Jon_Cupps',
#    'Gerold_Hightower',
#    'Leyton_Hightower',
#    'Rhea_Florent',
#    'Garth_Hightower',
#    'Jon_Cupps',
#    'Alysanne_Hightower',
#    'Arthur_Ambrose',
#    'Lynesse_Hightower',
#    'Jorah_Mormont',
#    'Baelor_Hightower',
#    'Rhonda_Rowan',
#    'Alerie_Hightower',
#    'Mace_Tyrell',
#    'Denyse_Hightower',
#    'Desmond_Redwyne',
#    'Gunthor_Hightower',
#    'Jeyne_Fossoway',
#    'Willas_Tyrell',
#    'Garlan_Tyrell',
#    'Loras_Tyrell',
#    'Margaery_Tyrell',
#    'Denys_Redwyne']},
#  {'Hugo_Wull': ['Hugo_Wull',
#    'Jon_Snow',
#    'Stannis_Baratheon',
#    'Dreadfort',
#    'Castle_Black',
#    'Roose_Bolton',
#    'Winterfell',
#    'Arya_Stark',
#    'Ramsay_Snow',
#    'Deepwood_Motte',
#    'Corliss_Penny',
#    'Roose_Bolton',
#    'Stannis_Baratheon',
#    'Winterfell',
#    'Eddard_Stark',
#    'Jeyne_Poole',
#    'Corliss_Penny']},
#  {'Terrence_Kenning': ['Terrence_Kenning']},
#  {'Walton_Frey': ['Walton_Frey',
#    'House_Frey',
#    'Deana_Hardyng',
#    'House_Frey',
#    'Stevron_Frey',
#    'Marsella_Waynwood',
#    'Deana_Hardyng',
#    'Steffon_Frey',
#    'Walda_Frey_(daughter_of_Walton)',
#    'Bryan_Frey',
#    'Walder_Frey',
#    'Stevron_Frey',
#    'Marsella_Waynwood',
#    'Jeyne_Lydden',
#    'Ryman_Frey',
#    'Aegon_Frey_(son_of_Stevron)',
#    'Maegelle_Frey',
#    'Dafyn_Vance',
#    'Deana_Hardyng',
#    'Edwyn_Frey',
#    'Walder_Frey_(son_of_Ryman)',
#    'Petyr_Frey',
#    'Mylenda_Caron',
#    'Marianne_Vance',
#    'Walder_Vance',
#    'Patrek_Vance',
#    'Steffon_Frey',
#    'Walda_Frey_(daughter_of_Walton)',
#    'Bryan_Frey',
#    'Walda_Frey_(daughter_of_Edwyn)',
#    'Perra_Frey']},
#  {'Galbart_Glover': ['Galbart_Glover',
#    'Deepwood_Motte',
#    'Larence_Snow',
#    'Gawen_Glover',
#    'Deepwood_Motte',
#    'Robett_Glover',
#    'Eddard_Stark',
#    'Catelyn_Stark',
#    'Helman_Tallhart',
#    'Robb_Stark',
#    'Winterfell',
#    'Robett_Glover',
#    'Walder_Frey',
#    'Joffrey_Baratheon',
#    'Riverrun',
#    'Deepwood_Motte',
#    'Balon_Greyjoy',
#    'Asha_Greyjoy',
#    'Westerlands',
#    'Martyn_Lannister',
#    'Edmure_Tully',
#    'Brynden_Tully',
#    'Victarion_Greyjoy',
#    'Jason_Mallister',
#    'Maege_Mormont',
#    'Seagard',
#    'Greywater_Watch',
#    'Stannis_Baratheon',
#    'Walder_Frey',
#    'Robb_Stark',
#    'Brynden_Tully',
#    'Robb_Stark',
#    'Catelyn_Stark',
#    'Deepwood_Motte',
#    'Asha_Greyjoy',
#    'Deepwood_Motte',
#    'Asha_Greyjoy',
#    'Robett_Glover',
#    'Sybelle_Glover',
#    'Gawen_Glover',
#    'Erena_Glover',
#    'Galbart_Glover']},
#  {'Beck': ['Beck', 'House_Lannister']},
#  {'Valarr_Targaryen': ['Valarr_Targaryen',
#    'Hand_of_the_King',
#    'House_Targaryen',
#    'Crownlands',
#    'King%27s_Landing',
#    'The_Hedge_Knight',
#    'House_Targaryen',
#    'Baelor_Targaryen_(son_of_Daeron_II)',
#    'Baelor_Targaryen_(son_of_Daeron_II)',
#    'Baelor_Targaryen_(son_of_Daeron_II)',
#    'Matarys_Targaryen',
#    'Lord_Ashford',
#    'Tourney_at_Ashford_Meadow',
#    'House_Targaryen',
#    'Daeron_II_Targaryen',
#    'Abelar_Hightower',
#    'Gawen_Swann',
#    'Baelor_Targaryen_(son_of_Daeron_II)',
#    'Matarys_Targaryen',
#    'Daeron_II_Targaryen',
#    'Aegon_V_Targaryen',
#    'Hand_of_the_King',
#    'Brynden_Rivers',
#    'Daeron_II_Targaryen',
#    'Baelor_Targaryen_(son_of_Daeron_II)',
#    'Aerys_I_Targaryen',
#    'Aelinor_Penrose',
#    'Rhaegel_Targaryen',
#    'Maekar_I_Targaryen',
#    'Matarys_Targaryen',
#    'Aerion_Targaryen',
#    'Daeron_Targaryen_(son_of_Maekar_I)',
#    'Daella_Targaryen_(daughter_of_Maekar_I)',
#    'Aegon_V_Targaryen',
#    'Rhae_Targaryen',
#    'House_Targaryen',
#    'Baelor_Targaryen_(son_of_Daeron_II)',
#    'Aegon_I_Targaryen',
#    'The_Hedge_Knight',
#    'Hand_of_the_King',
#    'Orys_Baratheon',
#    'Edmyn_Tully',
#    'Maegor_I_Targaryen',
#    'Murmison',
#    'Barth',
#    'Ryam_Redwyne',
#    'Otto_Hightower',
#    'Lyonel_Strong',
#    'Otto_Hightower',
#    'Criston_Cole',
#    'Cregan_Stark',
#    'Tyland_Lannister',
#    'Viserys_II_Targaryen',
#    'Ambrose_Butterwell',
#    'Baelor_Targaryen_(son_of_Daeron_II)',
#    'Brynden_Rivers',
#    'Tywin_Lannister',
#    'Jon_Connington',
#    'Qarlton_Chelsted',
#    'Rossart',
#    'Jon_Arryn',
#    'Eddard_Stark',
#    'Tyrion_Lannister',
#    'Tywin_Lannister',
#    'Harys_Swyft',
#    'Orton_Merryweather',
#    'Mace_Tyrell',
#    'Corlys_Velaryon',
#    'Mace_Tyrell',
#    'Alester_Florent',
#    'Davos_Seaworth',
#    'Axell_Florent',
#    'Jon_Connington',
#    'Barristan_Selmy',
#    'Myles_Smallwood']},
#  {'Chayle': ['Chayle',
#    'Winterfell',
#    'Hodor',
#    'Aethelmure',
#    'Tyrion_Lannister',
#    'Winterfell',
#    'Bran_Stark',
#    'Oldtown',
#    'Jojen_Reed',
#    'Palla',
#    'Theon_Greyjoy',
#    'Drowned_God',
#    'Bran_Stark',
#    'Theon_Greyjoy',
#    'Cellador']},
#  {'Hoster_Frey': ['Hoster_Frey',
#    'House_Frey',
#    'Whalen_Frey',
#    'Damon_Paege',
#    'Walder_Frey',
#    'Alyssa_Blackwood',
#    'Lothar_Frey',
#    'Leonella_Lefford',
#    'Jammos_Frey',
#    'Sallei_Paege',
#    'Whalen_Frey',
#    'Sylwa_Paege',
#    'Morya_Frey',
#    'Flement_Brax',
#    'Tyta_Frey',
#    'Walder_Frey_(son_of_Jammos)',
#    'Dickon_Frey',
#    'Mathis_Frey',
#    'Robert_Brax_(son_of_Flement)',
#    'Walder_Brax',
#    'Jon_Brax',
#    'Tysane_Frey',
#    'Walda_Frey_(daughter_of_Lothar)',
#    'Emberlei_Frey',
#    'Leana_Frey',
#    'Merianne_Frey']},
#  {'Cerenna_Lannister': ['Cerenna_Lannister',
#    'Cerenna_Lannister',
#    'House_Lannister',
#    'House_Lannister',
#    'Stafford_Lannister',
#    'Daven_Lannister',
#    'Myrielle_Lannister',
#    'Jason_Lannister_(son_of_Gerold)',
#    'Tywin_Lannister',
#    'Joanna_Lannister',
#    'Stafford_Lannister',
#    'Damon_Lannister_(son_of_Jason)',
#    'Tyrion_Lannister',
#    'Jaime_Lannister',
#    'Cersei_Lannister',
#    'Daven_Lannister',
#    'Myrielle_Lannister',
#    'Shiera_Crakehall',
#    'Damion_Lannister',
#    'Joffrey_Baratheon',
#    'Margaery_Tyrell',
#    'Myrcella_Baratheon',
#    'Tommen_Baratheon',
#    'Margaery_Tyrell',
#    'Lucion_Lannister',
#    'Lanna_Lannister',
#    'Antario_Jast']},
#  {'Quenton_Greyjoy': ['Quenton_Greyjoy',
#    'Quellon_Greyjoy',
#    'Quellon_Greyjoy',
#    'Harlon_Greyjoy',
#    'Donel_Greyjoy',
#    'Balon_Greyjoy',
#    'Alannys_Harlaw',
#    'Euron_Greyjoy',
#    'Victarion_Greyjoy',
#    'Urrigon_Greyjoy',
#    'Aeron_Greyjoy',
#    'Robin_Greyjoy',
#    'Rodrik_Greyjoy',
#    'Maron_Greyjoy',
#    'Asha_Greyjoy',
#    'Theon_Greyjoy']},
#  {'Leslyn_Haigh': ['Leslyn_Haigh',
#    'Knight',
#    'Perriane_Frey',
#    'Knight',
#    'Perriane_Frey',
#    'Harys_Haigh',
#    'Donnel_Haigh',
#    'Alyn_Haigh',
#    'Catelyn_Stark',
#    'Edmure_Tully',
#    'Perriane_Frey',
#    'Harys_Haigh',
#    'Donnel_Haigh',
#    'Alyn_Haigh',
#    'Walder_Haigh']},
#  {'Ronnel_Stout': ['Ronnel_Stout',
#    'Roose_Bolton',
#    'Kyle_Condon',
#    'House_Lannister']},
#  {'Robb_Reyne': ['Robb_Reyne',
#    'Knight',
#    'Knight',
#    'Daeron_II_Targaryen',
#    'Daemon_I_Blackfyre',
#    'First_Blackfyre_Rebellion']},
#  {'Jon_Cupps': ['Jon_Cupps',
#    'Knight',
#    'Leyla_Hightower',
#    'Knight',
#    'Leyla_Hightower',
#    'Leyton_Hightower']},
#  {'Andar_Royce': ['Andar_Royce',
#    'Knight',
#    'Runestone',
#    'Knight',
#    'Yohn_Royce',
#    'Runestone',
#    'Robar_Royce',
#    'Jaime_Lannister',
#    'Kingsguard',
#    'Yohn_Royce',
#    'Robar_Royce',
#    'Waymar_Royce',
#    'Ysilla_Royce',
#    'Mychel_Redfort']},
#  {'Gelmarr': ['Gelmarr',
#    'Winterfell',
#    'Theon_Greyjoy',
#    'Bran_Stark',
#    'Rickon_Stark',
#    'Aggar',
#    'Gynir',
#    'Ramsay_Snow',
#    'Ramsay_Snow',
#    'Farlen',
#    'Winterfell',
#    'Roose_Bolton',
#    'Aggar',
#    'Gynir']},
#  {'Dunstan_Drumm': ['Dunstan_Drumm',
#    'Erik_Ironmaker',
#    'Iron_Islands',
#    'Balon_Greyjoy',
#    'Dagmer',
#    'Pyke',
#    'Denys_Drumm',
#    'Donnel_Drumm',
#    'Dale_Drumm',
#    'Gormond_Drumm',
#    'Euron_Greyjoy',
#    'Victarion_Greyjoy',
#    'Rodrik_Harlaw',
#    'Gorold_Goodbrother',
#    'Southshield',
#    'Pyke',
#    'Vickon_Greyjoy',
#    'Denys_Drumm',
#    'Donnel_Drumm']},
#  {'Beren_Tallhart': ['Beren_Tallhart',
#    'Leobald_Tallhart',
#    'Torrhen%27s_Square',
#    'Berena_Hornwood',
#    'Halys_Hornwood',
#    'Daryn_Hornwood',
#    'Leobald_Tallhart',
#    'Donella_Hornwood',
#    'Berena_Hornwood',
#    'Torrhen%27s_Square',
#    'Berena_Hornwood',
#    'Brandon_Tallhart',
#    'Dagmer',
#    'Helman_Tallhart',
#    'Leobald_Tallhart',
#    'Berena_Hornwood',
#    'Benfred_Tallhart',
#    'Eddara_Tallhart',
#    'Brandon_Tallhart']},
#  {'Denys_Drumm': ['Denys_Drumm',
#    'Dunstan_Drumm',
#    'Dunstan_Drumm',
#    'Donnel_Drumm']},
#  {'Ryella_Frey': ['House_Frey',
#    'Arwood_Frey',
#    'Ryella_Royce',
#    'Walder_Frey',
#    'Amarei_Crakehall',
#    'Hosteen_Frey',
#    'Bellena_Hawick',
#    'Lucias_Vypren',
#    'Lythene_Frey',
#    'Symond_Frey',
#    'Betharios_of_Braavos',
#    'Danwell_Frey',
#    'Wynafrei_Whent',
#    'Arwood_Frey',
#    'Ryella_Royce',
#    'Damon_Vypren',
#    'Elyana_Vypren',
#    'Jon_Wylde',
#    'Alesander_Frey',
#    'Alyx_Frey',
#    'Bradamar_Frey',
#    'Androw_Frey',
#    'Alyn_Frey',
#    'Rickard_Wylde',
#    'Merrett_Frey',
#    'Mariya_Darry',
#    'Carolei_Waynwood',
#    'Pate_of_the_Blue_Fork',
#    'Amerei_Frey',
#    'Lancel_Lannister',
#    'Walda_Frey_(daughter_of_Merrett)',
#    'Roose_Bolton',
#    'Marissa_Frey',
#    'Walder_Frey_(son_of_Merrett)',
#    'Sandor_Frey',
#    'Cynthea_Frey',
#    'Raymund_Frey',
#    'Robert_Frey_(son_of_Raymund)',
#    'Malwyn_Frey',
#    'Sarra_Frey',
#    'Serra_Frey',
#    'Cersei_Frey',
#    'Tywin_Frey_(son_of_Raymund)',
#    'Jaime_Frey']},
#  {'Gladden_Wylde': ['Gladden_Wylde',
#    'Knight',
#    'Knight',
#    'Eddard_Stark',
#    'King%27s_Landing',
#    'Riverlands',
#    'Gregor_Clegane',
#    'Brotherhood_without_banners',
#    'House_Lannister']},
#  {'Mychel_Redfort': ['Mychel_Redfort',
#    'Knight',
#    'Ysilla_Royce',
#    'Horton_Redfort',
#    'Lyn_Corbray',
#    'Mya_Stone',
#    'Lyn_Corbray',
#    'Knight',
#    'Horton_Redfort',
#    'Knight',
#    'Yohn_Royce',
#    'Ysilla_Royce',
#    'Horton_Redfort',
#    'Jasper_Redfort',
#    'Creighton_Redfort',
#    'Jon_Redfort',
#    'Ysilla_Royce']},
#  {'Philip_Foote': ['Philip_Foote',
#    'Philip_Foote',
#    'Knight',
#    'Nightsong',
#    'Knight',
#    'Westerlands',
#    'House_Lannister',
#    'Bryce_Caron',
#    'Nightsong',
#    'Sansa_Stark',
#    'Tyrion_Lannister',
#    'Dorne',
#    'Oberyn_Martell',
#    'King%27s_Landing',
#    'Purple_Wedding',
#    'Margaery_Tyrell',
#    'Joffrey_Baratheon']},
#  {'Shiera_Seastar': ['House_Targaryen',
#    'Crownlands',
#    'Aegon_IV_Targaryen',
#    'Brynden_Rivers',
#    'Seven_Kingdoms',
#    'Aegon_IV_Targaryen',
#    'Brynden_Rivers',
#    'Aegor_Rivers',
#    'Hand_of_the_King',
#    'Aerys_I_Targaryen',
#    'Bran_Stark',
#    'Brynden_Rivers',
#    'Brynden_Rivers',
#    'Aegon_V_Targaryen',
#    'Aegor_Rivers',
#    'Brynden_Rivers',
#    'Bran_Stark',
#    'Aegor_Rivers',
#    'Brynden_Rivers',
#    'Seven_Kingdoms',
#    'Barristan_Selmy',
#    'Brynden_Rivers',
#    'Shiera_Seastar',
#    'Daemon_I_Blackfyre',
#    'Aegor_Rivers',
#    'Brynden_Rivers']},
#  {'Humfrey_Clifton': ['Humfrey_Clifton',
#    'Knight',
#    'Knight',
#    'Stannis_Baratheon',
#    'Stannis_Baratheon',
#    'Ned_Woods']},
#  {'Ygritte': ['Ygritte',
#    'Mance_Rayder',
#    'Castle_Black',
#    'Spearwife',
#    'Jon_Snow',
#    'Orell',
#    'Night%27s_Watch',
#    'Jon_Snow',
#    'Stonesnake',
#    'Qhorin_Halfhand',
#    'Mance_Rayder',
#    'Tormund',
#    'Styr',
#    'Castle_Black',
#    'Bran_Stark',
#    'Jon_Snow',
#    'Jon_Snow',
#    'Jon_Snow',
#    'Jon_Snow',
#    'Jon_Snow']},
#  {'Emphyria_Vance': ['Emphyria_Vance',
#    'Karyl_Vance',
#    'Karyl_Vance',
#    'Liane_Vance',
#    'Rhialta_Vance']},
#  {'Greydon_Goodbrother': ['Greydon_Goodbrother',
#    'Gorold_Goodbrother',
#    'Gran_Goodbrother',
#    'Gormond_Goodbrother',
#    'Gorold_Goodbrother',
#    'Balon_Greyjoy',
#    'Gorold_Goodbrother',
#    'Gwin_Goodbrother',
#    'Gysella_Goodbrother',
#    'Gormond_Goodbrother',
#    'Gran_Goodbrother']},
#  {'Rickard_Tyrell': ['Olymer_Tyrell',
#    'Lysa_Meadows',
#    'Luthor_Tyrell',
#    'Gormon_Tyrell',
#    'Garth_Tyrell',
#    'Moryn_Tyrell',
#    'Mace_Tyrell',
#    'Alerie_Hightower',
#    'Jon_Fossoway',
#    'Mina_Tyrell',
#    'Paxter_Redwyne',
#    'Garse_Flowers',
#    'Garrett_Flowers',
#    'Luthor_Tyrell_(son_of_Moryn)',
#    'Elyn_Norridge',
#    'Willas_Tyrell',
#    'Garlan_Tyrell',
#    'Leonette_Fossoway',
#    'Horas_Redwyne',
#    'Hobber_Redwyne',
#    'Lia_Serry',
#    'Theodore_Tyrell',
#    'Olene_Tyrell',
#    'Leo_Blackbar',
#    'Medwick_Tyrell',
#    'Loras_Tyrell',
#    'Renly_Baratheon',
#    'Margaery_Tyrell',
#    'Joffrey_Baratheon',
#    'Elinor_Tyrell',
#    'Luthor_Tyrell_(son_of_Theodore)',
#    'Tommen_Baratheon',
#    'Quentin_Tyrell',
#    'Normund_Tyrell',
#    'Victor_Tyrell',
#    'Olymer_Tyrell',
#    'Lysa_Meadows',
#    'Jon_Bulwer',
#    'Victaria_Tyrell',
#    'Leo_Tyrell_(son_of_Victor)',
#    'Raymund_Tyrell',
#    'Megga_Tyrell',
#    'Alysanne_Bulwer',
#    'Lyonel_Tyrell_(son_of_Leo)',
#    'Alla_Tyrell',
#    'Lucas_Tyrell',
#    'Lorent_Tyrell',
#    'Leona_Tyrell']},
#  {'Karlon_Stark': ['Karlon_Stark',
#    'Karhold',
#    'House_Stark',
#    'House_Karstark',
#    'Karhold',
#    'House_Karstark',
#    'Karhold',
#    'House_Karstark']},
#  {'Ronel_Rivers': ['House_Frey',
#    'Walder_Frey',
#    'Catelyn_Stark',
#    'Robb_Stark',
#    'Walder_Frey',
#    'House_Frey',
#    'Arya_Stark',
#    'Harrenhal',
#    'Roose_Bolton',
#    'Harrenhal']},
#  {'Dywen': ['Night%27s_Watch',
#    'Night%27s_Watch',
#    'Jon_Snow',
#    'Samwell_Tarly',
#    'Jeor_Mormont',
#    'Othor',
#    'Jafer_Flowers',
#    'Castle_Black',
#    'Chett',
#    'Samwell_Tarly',
#    'Grenn',
#    'Kedge_Whiteye',
#    'Richard_Horpe',
#    'Justin_Massey',
#    'Weeper',
#    'Bowen_Marsh',
#    'Jon_Snow',
#    'Alliser_Thorne',
#    'Melisandre',
#    'Castle_Black',
#    'Owen_the_Oaf',
#    'Castle_Black',
#    'Jon_Snow']},
#  {'Brandon_Stark': ['House_Stark',
#    'Winterfell',
#    'King%27s_Landing',
#    'Rickard_Stark',
#    'Winterfell',
#    'Eddard_Stark',
#    'Lyanna_Stark',
#    'Benjen_Stark',
#    'Barbrey_Dustin',
#    'Winterfell',
#    'Rickard_Stark',
#    'Willam_Dustin',
#    'Rills',
#    'Barbrey_Dustin',
#    'Riverrun',
#    'Eddard_Stark',
#    'Rickard_Stark',
#    'Howland_Reed',
#    'Lyanna_Stark',
#    'Ashara_Dayne',
#    'Rhaegar_Targaryen',
#    'Elia_Martell',
#    'Riverrun',
#    'Petyr_Baelish',
#    'Hoster_Tully',
#    'Edmure_Tully',
#    'Rickard_Stark',
#    'Riverrun',
#    'Rickard_Stark',
#    'Rhaegar_Targaryen',
#    'Ethan_Glover',
#    'Kyle_Royce',
#    'Elbert_Arryn',
#    'Jeffory_Mallister',
#    'King%27s_Landing',
#    'Aerys_II_Targaryen',
#    'Tyrosh',
#    'Winterfell',
#    'Eddard_Stark',
#    'Eddard_Stark',
#    'Bran_Stark',
#    'Theon_Greyjoy',
#    'Winterfell',
#    'Rickon_Stark',
#    'Osha',
#    'Hodor',
#    'Catelyn_Stark',
#    'Jaime_Lannister',
#    'Theon_Greyjoy',
#    'Barbrey_Dustin',
#    'Barbrey_Dustin',
#    'Winterfell',
#    'Hand_of_the_King',
#    'Eddard_Stark',
#    'Catelyn_Stark',
#    'Hoster_Tully',
#    'Eddard_Stark',
#    'Jaime_Lannister',
#    'Barbrey_Dustin',
#    'Theon_Greyjoy',
#    'Beron_Stark',
#    'Donnor_Stark',
#    'Willam_Stark',
#    'Artos_Stark',
#    'Rodrik_Stark_(son_of_Beron)',
#    'Edwyle_Stark',
#    'Rickard_Stark',
#    'Catelyn_Stark',
#    'Eddard_Stark',
#    'Lyanna_Stark',
#    'Benjen_Stark',
#    'Jeyne_Westerling',
#    'Robb_Stark',
#    'Sansa_Stark',
#    'Tyrion_Lannister',
#    'Arya_Stark',
#    'Bran_Stark',
#    'Rickon_Stark',
#    'Jon_Snow',
#    'Benjen_Stark']},
#  {'Roger_Hogg': ['Roger_Hogg',
#    'Knight',
#    'Knight',
#    'Jaime_Lannister',
#    'Riverrun',
#    'House_Karstark',
#    'House_Lannister',
#    'Amory_Lorch',
#    'Kennos_of_Kayce',
#    'Lyle_Crakehall']},
#  {'Three_Toes': ['Brave_Companions',
#    'Brave_Companions',
#    'Jaime_Lannister',
#    'Vargo_Hoat']},
#  {'Olyvar_Frey': ['House_Frey',
#    'House_Frey',
#    'Walder_Frey',
#    'Bethany_Rosby',
#    'Robb_Stark',
#    'Catelyn_Stark',
#    'Walder_Frey',
#    'House_Frey',
#    'House_Stark',
#    'Cleos_Frey',
#    'Jeyne_Westerling',
#    'Rollam_Westerling',
#    'Roslin_Frey',
#    'Edmure_Tully',
#    'Ryman_Frey',
#    'Robb_Stark',
#    'Ryman_Frey',
#    'Walder_Frey',
#    'Bethany_Rosby',
#    'Perwyn_Frey',
#    'Benfrey_Frey',
#    'Jyanna_Frey',
#    'Willamen_Frey',
#    'Roslin_Frey',
#    'Edmure_Tully',
#    'Della_Frey',
#    'Osmund_Frey']},
#  {'Jorah_Mormont': ['Jorah_Mormont',
#    'Knight',
#    'House_Targaryen',
#    'Second_Sons',
#    'Lynesse_Hightower',
#    'Knight',
#    'Bear_Island',
#    'House_Targaryen',
#    'Daenerys_Targaryen',
#    'Barristan_Selmy',
#    'Daenerys_Targaryen',
#    'Dothraki',
#    'Jeor_Mormont',
#    'Bear_Island',
#    'Night%27s_Watch',
#    'Sack_of_King%27s_Landing',
#    'Balon_Greyjoy',
#    'Greyjoy%27s_Rebellion',
#    'Knight',
#    'Illyrio_Mopatis',
#    'Pyke',
#    'Lynesse_Hightower',
#    'Jaime_Lannister',
#    'Leyton_Hightower',
#    'Bear_Island',
#    'Oldtown',
#    'Braavos',
#    'Seven_Kingdoms',
#    'Eddard_Stark',
#    'Tyrosh',
#    'Maege_Mormont',
#    'Castle_Black',
#    'Braavos',
#    'Lys',
#    'Braavos',
#    'Tregar_Ormollen',
#    'Dothraki',
#    'Ben_Plumm',
#    'Second_Sons',
#    'Varys',
#    'Pentos',
#    'Daenerys_Targaryen',
#    'Dothraki',
#    'Viserys_Targaryen',
#    'Drogo',
#    'Seven_Kingdoms',
#    'Varys',
#    'King%27s_Landing',
#    'Illyrio_Mopatis',
#    'Ogo',
#    'Lhazareen',
#    'Mirri_Maz_Duur',
#    'Asshai',
#    'Qotho',
#    'Bloodrider',
#    'Daenerys_Targaryen',
#    'Rhaego',
#    'Qarth',
#    'Asshai',
#    'Rakharo',
#    'Lynesse_Hightower',
#    'Qarth',
#    'Xaro_Xhoan_Daxos',
#    'Pyat_Pree',
#    'Quaithe',
#    'Seven_Kingdoms',
#    'Quhuru_Mo',
#    'Joffrey_Baratheon',
#    'Stannis_Baratheon',
#    'Renly_Baratheon',
#    'Asshai',
#    'Illyrio_Mopatis',
#    'Mirri_Maz_Duur',
#    'Belwas',
#    'Barristan_Selmy',
#    'Pentos',
#    'Pentos',
#    'House_Targaryen',
#    'Rhaegar_Targaryen',
#    'Lynesse_Hightower',
#    'Illyrio_Mopatis',
#    'Unsullied',
#    'Sack_of_King%27s_Landing',
#    'Grey_Worm',
#    'Mero',
#    'Second_Sons',
#    'Daario_Naharis',
#    'Stormcrows',
#    'Barristan_Selmy',
#    'Lord_Commander_of_the_Kingsguard',
#    'Drogo',
#    'Viserys_Targaryen',
#    'Jeor_Mormont',
#    'Samwell_Tarly',
#    'Night%27s_Watch',
#    'Daenerys_Targaryen',
#    'Tyrion_Lannister',
#    'Varys',
#    'Pentos',
#    'Penny',
#    'Knight',
#    'Qarth',
#    'Tyrion_Lannister',
#    'Hizdahr_zo_Loraq',
#    'Second_Sons',
#    'Ben_Plumm',
#    'House_Targaryen',
#    'Daenerys_Targaryen',
#    'Ben_Plumm',
#    'Second_Sons',
#    'Unsullied',
#    'Barristan_Selmy',
#    'Daenerys_Targaryen',
#    'Qotho',
#    'Viserys_Targaryen',
#    'House_Targaryen',
#    'Daenerys_Targaryen',
#    'Daenerys_Targaryen',
#    'Lynesse_Hightower',
#    'Daenerys_Targaryen',
#    'Lynesse_Hightower',
#    'Daenerys_Targaryen',
#    'Qarth',
#    'Daenerys_Targaryen',
#    'Daenerys_Targaryen',
#    'Daenerys_Targaryen',
#    'Eddard_Stark',
#    'Eddard_Stark',
#    'Daenerys_Targaryen',
#    'Viserys_Targaryen',
#    'Daenerys_Targaryen',
#    'Daenerys_Targaryen',
#    'Tyrion_Lannister',
#    'Daenerys_Targaryen',
#    'Hizdahr_zo_Loraq',
#    'Tyrion_Lannister',
#    'Second_Sons',
#    'Jeor_Mormont',
#    'Maege_Mormont',
#    'Lynesse_Hightower',
#    'Dacey_Mormont',
#    'Alysane_Mormont',
#    'Lyra_Mormont',
#    'Jorelle_Mormont',
#    'Lyanna_Mormont',
#    'Alliser_Thorne']},
#  {'Brynden_Tully': ['Brynden_Tully',
#    'Knight',
#    'Riverrun',
#    'House_Tully',
#    'House_Stark',
#    'Riverlands',
#    'Riverrun',
#    'Knight',
#    'House_Tully',
#    'Hoster_Tully',
#    'Catelyn_Stark',
#    'Lysa_Arryn',
#    'Edmure_Tully',
#    'Hoster_Tully',
#    'Norbert_Vance',
#    'Knight',
#    'Seven_Kingdoms',
#    'Riverrun',
#    'Bethany_Redwyne',
#    'Jonos_Bracken',
#    'Walder_Frey',
#    'Catelyn_Stark',
#    'Lysa_Arryn',
#    'Edmure_Tully',
#    'Petyr_Baelish',
#    'Brandon_Stark',
#    'Tywin_Lannister',
#    'Jaime_Lannister',
#    'Sumner_Crakehall',
#    'Riverrun',
#    'Catelyn_Stark',
#    'Brandon_Stark',
#    'Rickard_Stark',
#    'Aerys_II_Targaryen',
#    'Eddard_Stark',
#    'House_Tully',
#    'Hoster_Tully',
#    'Lysa_Arryn',
#    'Jon_Arryn',
#    'Riverrun',
#    'Bloody_Gate',
#    'Catelyn_Stark',
#    'Bloody_Gate',
#    'Tyrion_Lannister',
#    'House_Lannister',
#    'Riverlands',
#    'Lysa_Arryn',
#    'Riverrun',
#    'House_Tully',
#    'White_Harbor',
#    'Robb_Stark',
#    'Addam_Marbrand',
#    'Edmure_Tully',
#    'Jaime_Lannister',
#    'Walder_Frey',
#    'Roose_Bolton',
#    'Theon_Greyjoy',
#    'Bethany_Redwyne',
#    'Hoster_Tully',
#    'Tywin_Lannister',
#    'House_Stark',
#    'House_Tully',
#    'Harrenhal',
#    'Westerlands',
#    'Martyn_Rivers',
#    'Vyman',
#    'Riverrun',
#    'Rickard_Karstark',
#    'Tion_Frey',
#    'Willem_Lannister',
#    'House_Karstark',
#    'House_Frey',
#    'Jeyne_Westerling',
#    'Roslin_Frey',
#    'Galbart_Glover',
#    'Brotherhood_without_banners',
#    'Arya_Stark',
#    'Sandor_Clegane',
#    'Emmon_Frey',
#    'Daven_Lannister',
#    'Ryman_Frey',
#    'Gawen_Westerling',
#    'Cersei_Lannister',
#    'Lord_Commander_of_the_Kingsguard',
#    'Sansa_Stark',
#    'Night%27s_Watch',
#    'Jon_Snow',
#    'Edwyn_Frey',
#    'Lyle_Crakehall',
#    'Norbert_Vance',
#    'Clement_Piper',
#    'Forley_Prester',
#    'Jonos_Bracken',
#    'Tytos_Blackwood',
#    'Raventree_Hall',
#    'Lysa_Arryn',
#    'Riverrun',
#    'House_Tully',
#    'Catelyn_Stark',
#    'Hoster_Tully',
#    'Bethany_Redwyne',
#    'Catelyn_Stark',
#    'Catelyn_Stark',
#    'House_Tully',
#    'Catelyn_Stark',
#    'Catelyn_Stark',
#    'Seven_Kingdoms',
#    'Jaime_Lannister',
#    'Roslin_Frey',
#    'Edmure_Tully',
#    'Catelyn_Stark',
#    'Jaime_Lannister',
#    'Robb_Stark',
#    'Robb_Stark',
#    'Catelyn_Stark',
#    'Arya_Stark',
#    'House_Tully',
#    'Tom_of_Sevenstreams',
#    'Beric_Dondarrion',
#    'Hoster_Tully',
#    'Genna_Lannister',
#    'Jaime_Lannister',
#    'Jaime_Lannister',
#    'Hoster_Tully',
#    'Catelyn_Stark',
#    'Eddard_Stark',
#    'Jon_Arryn',
#    'Lysa_Arryn',
#    'Petyr_Baelish',
#    'Edmure_Tully',
#    'Roslin_Frey',
#    'House_Stark']},
#  {'Gariss': ['Gariss',
#    'House_Stark',
#    'House_Stark',
#    'Winterfell',
#    'Theon_Greyjoy',
#    'Bran_Stark',
#    'Rickon_Stark']},
#  {'Yellow_Dick': ['Winterfell',
#    'Bastard%27s_Boys',
#    'Dreadfort',
#    'Walder_Frey_(son_of_Merrett)',
#    'Walder_Frey_(son_of_Jammos)',
#    'Theon_Greyjoy',
#    'Ramsay_Snow',
#    'Arnolf_Karstark',
#    'Hother_Umber',
#    'Bastard%27s_Boys',
#    'Jeyne_Poole',
#    'Winterfell',
#    'Roose_Bolton',
#    'Stannis_Baratheon',
#    'Knight',
#    'Holly',
#    'Rowan',
#    'Spearwife',
#    'Theon_Greyjoy',
#    'Rowan']},
#  {'Willam_Wells': ['Willam_Wells',
#    'Knight',
#    'Knight',
#    'Dorne',
#    'Quentyn_Martell',
#    'Daenerys_Targaryen',
#    'House_Martell',
#    'Daenerys_Targaryen',
#    'Quentyn_Martell',
#    'Cletus_Yronwood',
#    'Gerris_Drinkwater',
#    'Archibald_Yronwood',
#    'Kedry']},
#  {'Darlessa_Marbrand': ['House_Lannister',
#    'Tygett_Lannister',
#    'Tygett_Lannister',
#    'Tyrek_Lannister',
#    'Tytos_Lannister',
#    'Tywin_Lannister',
#    'Joanna_Lannister',
#    'Kevan_Lannister',
#    'Emmon_Frey',
#    'Genna_Lannister',
#    'Tygett_Lannister',
#    'Gerion_Lannister',
#    'Cersei_Lannister',
#    'Jaime_Lannister',
#    'Tyrion_Lannister',
#    'Sansa_Stark',
#    'Tyrek_Lannister',
#    'Ermesande_Hayford',
#    'Joy_Hill',
#    'Joffrey_Baratheon',
#    'Myrcella_Baratheon',
#    'Tommen_Baratheon',
#    'Amerei_Frey',
#    'Lancel_Lannister',
#    'Martyn_Lannister',
#    'Willem_Lannister',
#    'Janei_Lannister']},
#  {'Rosamund_Lannister': ['Myrcella_Baratheon',
#    'Dorne',
#    'Tyrion_Lannister',
#    'Arys_Oakheart',
#    'Arianne_Martell',
#    'Sunspear']},
#  {'Walder_Vance': ['Walder_Vance',
#    'Dafyn_Vance',
#    'Maegelle_Frey',
#    'Walder_Frey',
#    'Stevron_Frey',
#    'Marsella_Waynwood',
#    'Jeyne_Lydden',
#    'Ryman_Frey',
#    'Aegon_Frey_(son_of_Stevron)',
#    'Maegelle_Frey',
#    'Dafyn_Vance',
#    'Walton_Frey',
#    'Deana_Hardyng',
#    'Edwyn_Frey',
#    'Walder_Frey_(son_of_Ryman)',
#    'Petyr_Frey',
#    'Mylenda_Caron',
#    'Marianne_Vance',
#    'Patrek_Vance',
#    'Steffon_Frey',
#    'Walda_Frey_(daughter_of_Walton)',
#    'Bryan_Frey',
#    'Walda_Frey_(daughter_of_Edwyn)',
#    'Perra_Frey']},
#  {'Lyonel_Tyrell_(lord)': ['Highgarden',
#    'Highgarden',
#    'Dance_of_the_Dragons',
#    'Dance_of_the_Dragons',
#    'Ulf_the_White',
#    'Highgarden',
#    'House_Targaryen',
#    'Daeron_I_Targaryen',
#    'Dorne',
#    'Seven_Kingdoms']},
#  {'House_Osgrey': ['Standfast',
#    'Coldmoat',
#    'Standfast',
#    'Coldmoat',
#    'Perwyn_Osgrey',
#    'Wilbert_Osgrey',
#    'King_of_the_Rock',
#    'Ormond_Osgrey',
#    'Maegor_I_Targaryen',
#    'First_Blackfyre_Rebellion',
#    'Eustace_Osgrey',
#    'Daemon_I_Blackfyre',
#    'Daeron_II_Targaryen',
#    'Alysanne_Osgrey',
#    'Standfast',
#    'Rohanne_Webber',
#    'Addam_Osgrey',
#    'Lucas_Inchfield',
#    'Perwyn_Osgrey',
#    'Coldmoat',
#    'Wilbert_Osgrey',
#    'Gyles_III_Gardener',
#    'Highgarden',
#    'Ormond_Osgrey',
#    'Coldmoat',
#    'Maegor_I_Targaryen',
#    'Eustace_Osgrey',
#    'Standfast',
#    'Coldmoat',
#    'Edwyn_Osgrey',
#    'Harrold_Osgrey',
#    'Addam_Osgrey',
#    'Alysanne_Osgrey',
#    'House_Tarly',
#    'House_Fossoway_of_Cider_Hall',
#    'House_Fossoway_of_New_Barrel',
#    'House_Tarly',
#    'House_Fossoway_of_Cider_Hall',
#    'House_Fossoway_of_New_Barrel']},
#  {'Kegs': ['Night%27s_Watch',
#    'Night%27s_Watch',
#    'Bowen_Marsh',
#    'Castle_Black',
#    'Satin',
#    'Giants',
#    'Jon_Snow']},
#  {'Hizdahr_zo_Loraq': ['Hizdahr_zo_Loraq',
#    'Daenerys_Targaryen',
#    'Daenerys_Targaryen',
#    'Mazdhan_zo_Loraq',
#    'Hazrak_zo_Loraq',
#    'Zharaq_zo_Loraq',
#    'Daenerys_Targaryen',
#    'Barristan_Selmy',
#    'Lys',
#    'Qarth',
#    'Khrazz',
#    'Spotted_Cat',
#    'Galazza_Galare',
#    'Skahaz_mo_Kandaq',
#    'Belwas',
#    'Grey_Worm',
#    'Unsullied',
#    'Barristan_Selmy',
#    'Marghaz_zo_Loraq',
#    'Bloodbeard',
#    'Groleo',
#    'Aerys_II_Targaryen',
#    'Jaehaerys_II_Targaryen',
#    'Grey_Worm',
#    'Daenerys_Targaryen',
#    'Daenerys_Targaryen',
#    'Daenerys_Targaryen',
#    'Daenerys_Targaryen',
#    'Daenerys_Targaryen',
#    'Barristan_Selmy',
#    'House_Targaryen',
#    'Visenya_Targaryen',
#    'Rhaenys_Targaryen',
#    'Jeyne_Westerling_(wife_of_Maegor_I)',
#    'Alysanne_Targaryen',
#    'Aemma_Arryn',
#    'Alicent_Hightower',
#    'Helaena_Targaryen',
#    'Jaehaera_Targaryen',
#    'Daena_Targaryen',
#    'Naerys_Targaryen',
#    'Aelinor_Penrose',
#    'Rhaella_Targaryen',
#    'Daemon_Targaryen',
#    'Drogo',
#    'House_Baratheon',
#    'Cersei_Lannister',
#    'Margaery_Tyrell',
#    'Selyse_Florent',
#    'Margaery_Tyrell',
#    'Alannys_Harlaw',
#    'House_Stark',
#    'Jeyne_Westerling']},
#  {'Alyn_Ambrose': ['Arthur_Ambrose',
#    'Alysanne_Hightower',
#    'Elinor_Tyrell',
#    'Elinor_Tyrell',
#    'Elinor_Tyrell',
#    'Myr',
#    'Megga_Tyrell',
#    'Sansa_Stark',
#    'Knight',
#    'Tyrion_Lannister',
#    'Joffrey_Baratheon',
#    'Margaery_Tyrell',
#    'Arthur_Ambrose',
#    'Alysanne_Hightower']},
#  {'Melisandre': ['Melisandre',
#    'R%27hllor',
#    'Asshai',
#    'R%27hllor',
#    'Asshai',
#    'Stannis_Baratheon',
#    'Dragonstone',
#    'Azor_Ahai',
#    'Knight',
#    'R%27hllor',
#    'Asshai',
#    'Dragonstone',
#    'Azor_Ahai',
#    'R%27hllor',
#    'Stannis_Baratheon',
#    'Selyse_Florent',
#    'Tywin_Lannister',
#    'Tyrion_Lannister',
#    'Varys',
#    'Stannis_Baratheon',
#    'Asshai',
#    'Dragonstone',
#    'Selyse_Florent',
#    'R%27hllor',
#    'Asshai',
#    'Azor_Ahai',
#    'Cressen',
#    'R%27hllor',
#    'King%27s_Landing',
#    'Petyr_Baelish',
#    'Shireen_Baratheon',
#    'Renly_Baratheon',
#    'Storm%27s_End',
#    'Loras_Tyrell',
#    'Bitterbridge',
#    'Cortnay_Penrose',
#    'Davos_Seaworth',
#    'Elwood_Meadows',
#    'Bryce_Caron',
#    'Tywin_Lannister',
#    'Mace_Tyrell',
#    'Garlan_Tyrell',
#    'Stannis_Baratheon',
#    'Azor_Ahai',
#    'Guncer_Sunglass',
#    'Hubard_Rambton',
#    'Dragonstone',
#    'Edric_Storm',
#    'Seven_Kingdoms',
#    'Balon_Greyjoy',
#    'Robb_Stark',
#    'Joffrey_Baratheon',
#    'Stannis_Baratheon',
#    'Pyke',
#    'Purple_Wedding',
#    'Castle_Black',
#    'Night%27s_Watch',
#    'Alester_Florent',
#    'Eastwatch-by-the-Sea',
#    'Orell',
#    'Varamyr',
#    'Jon_Snow',
#    'Winterfell',
#    'R%27hllor',
#    'Mance_Rayder',
#    'King-Beyond-the-Wall',
#    'Oldtown',
#    'Maekar_I_Targaryen',
#    'Gilly',
#    'Monster',
#    'Jon_Snow',
#    'Castle_Black',
#    'Devan_Seaworth',
#    'Ramsay_Snow',
#    'Arya_Stark',
#    'Jon_Snow',
#    'Hairy_Hal',
#    'Garth_Greyfeather',
#    'Weeper',
#    'Denys_Mallister',
#    'Shadow_Tower',
#    'Alys_Karstark',
#    'Cregan_Karstark',
#    'Karhold',
#    'Selyse_Florent',
#    'Cotter_Pyke',
#    'Knight',
#    'Davos_Seaworth',
#    'Davos_Seaworth',
#    'Azor_Ahai',
#    'Davos_Seaworth',
#    'Jon_Snow',
#    'Azor_Ahai',
#    'R%27hllor',
#    'Jon_Snow',
#    'Stannis_Baratheon',
#    'R%27hllor',
#    'Cressen',
#    'R%27hllor',
#    'Dragonstone',
#    'Cressen',
#    'Knight',
#    'Stannis_Baratheon',
#    'Davos_Seaworth',
#    'Stannis_Baratheon',
#    'Jon_Snow',
#    'Stannis_Baratheon',
#    'Will',
#    'Bran_Stark',
#    'Catelyn_Stark',
#    'Daenerys_Targaryen',
#    'Eddard_Stark',
#    'Jon_Snow',
#    'Tyrion_Lannister',
#    'Arya_Stark',
#    'Sansa_Stark',
#    'Cressen',
#    'Bran_Stark',
#    'Catelyn_Stark',
#    'Daenerys_Targaryen',
#    'Jon_Snow',
#    'Tyrion_Lannister',
#    'Arya_Stark',
#    'Sansa_Stark',
#    'Davos_Seaworth',
#    'Theon_Greyjoy',
#    'Chett',
#    'Bran_Stark',
#    'Catelyn_Stark',
#    'Daenerys_Targaryen',
#    'Jon_Snow',
#    'Tyrion_Lannister',
#    'Arya_Stark',
#    'Sansa_Stark',
#    'Davos_Seaworth',
#    'Jaime_Lannister',
#    'Samwell_Tarly',
#    'Merrett_Frey',
#    'Arya_Stark',
#    'Sansa_Stark',
#    'Jaime_Lannister',
#    'Samwell_Tarly',
#    'Cersei_Lannister',
#    'Aeron_Greyjoy',
#    'Areo_Hotah',
#    'Asha_Greyjoy',
#    'Arys_Oakheart',
#    'Victarion_Greyjoy',
#    'Arianne_Martell',
#    'Varamyr',
#    'Bran_Stark',
#    'Daenerys_Targaryen',
#    'Jon_Snow',
#    'Tyrion_Lannister',
#    'Arya_Stark',
#    'Davos_Seaworth',
#    'Theon_Greyjoy',
#    'Jaime_Lannister',
#    'Cersei_Lannister',
#    'Areo_Hotah',
#    'Asha_Greyjoy',
#    'Victarion_Greyjoy',
#    'Quentyn_Martell',
#    'Jon_Connington',
#    'Barristan_Selmy',
#    'Kevan_Lannister']},
#  {'Ossy': ['Ossy', 'Eyrie', 'Mya_Stone', 'Lothor_Brune']},
#  {'Malleon': ['Citadel', 'Jon_Arryn', 'Eddard_Stark']},
#  {'Jafer_Flowers': ['Night%27s_Watch',
#    'Night%27s_Watch',
#    'Benjen_Stark',
#    'Waymar_Royce',
#    'Jon_Snow',
#    'Castle_Black',
#    'Jaremy_Rykker']},
#  {'Moribald_Chester': ['King%27s_Landing']},
#  {'Gavin': ['Gavin',
#    'Tormund',
#    'Night%27s_Watch',
#    'Bowen_Marsh',
#    'Othell_Yarwyck',
#    'Jon_Snow',
#    'Harle_the_Handsome']},
#  {'Sherrit': ['Sherrit']},
#  {'Kennos_of_Kayce': ['Knight',
#    'Knight',
#    'Terrence_Kenning',
#    'Horn_of_Herrock',
#    'Knight',
#    'Sansa_Stark',
#    'Jaime_Lannister',
#    'King%27s_Landing',
#    'Horn_of_Herrock',
#    'Harrenhal',
#    'Riverrun']},
#  {'Arnell': ['Knight',
#    'Night%27s_Watch',
#    'Knight',
#    'Night%27s_Watch',
#    'House_Fossoway_of_New_Barrel',
#    'Jeor_Mormont',
#    'Renly_Baratheon']},
#  {'Rhaenys_Targaryen_(daughter_of_Aemon)': ['House_Targaryen',
#    'Crownlands',
#    'Corlys_Velaryon',
#    'Corlys_Velaryon',
#    'House_Targaryen',
#    'Dance_of_the_Dragons',
#    'Storm%27s_End',
#    'Jaehaerys_I_Targaryen',
#    'Corlys_Velaryon',
#    'Laena_Velaryon',
#    'Laenor_Velaryon',
#    'Harrenhal',
#    'Storm%27s_End',
#    'Winterfell',
#    'White_Harbor',
#    'Laena_Velaryon',
#    'Laenor_Velaryon',
#    'Viserys_I_Targaryen',
#    'Daemon_Targaryen',
#    'Rhaenyra_Targaryen',
#    'Dance_of_the_Dragons',
#    'Rhaenyra_Targaryen',
#    'Viserys_I_Targaryen',
#    'Dragonstone',
#    'Lord_Staunton',
#    'Criston_Cole',
#    'Aegon_II_Targaryen',
#    'Aemond_Targaryen',
#    'Corlys_Velaryon',
#    'Corlys_Velaryon',
#    'Gyldayn',
#    'Daella_Targaryen_(daughter_of_Jaehaerys_I)',
#    'Corlys_Velaryon',
#    'Aemma_Arryn',
#    'Viserys_I_Targaryen',
#    'Alicent_Hightower',
#    'Daemon_Targaryen',
#    'Rhea_Royce',
#    'Aegon_Targaryen_(son_of_Baelon)',
#    'Laena_Velaryon',
#    'Daemon_Targaryen',
#    'Laenor_Velaryon',
#    'Rhaenyra_Targaryen',
#    'Daemon_Targaryen',
#    'Baelon_Targaryen_(son_of_Viserys_I)',
#    'Aegon_II_Targaryen',
#    'Helaena_Targaryen',
#    'Aemond_Targaryen',
#    'Daeron_Targaryen_(son_of_Viserys_I)',
#    'Rhaena_Targaryen_(daughter_of_Daemon)',
#    'Baela_Targaryen',
#    'Aegon_III_Targaryen',
#    'Viserys_II_Targaryen',
#    'Jaehaerys_Targaryen_(son_of_Aegon_II)',
#    'Jaehaera_Targaryen',
#    'Maelor_Targaryen',
#    'Daemon_Targaryen',
#    'Rhea_Royce',
#    'Laena_Velaryon',
#    'Rhaenyra_Targaryen']},
#  {'Vickon_Greyjoy': ['Vickon_Greyjoy',
#    'Pyke',
#    'Iron_Islands',
#    'Grey_King',
#    'Aegon_I_Targaryen',
#    'Iron_Islands',
#    'Seven_Kingdoms',
#    'Drowned_God',
#    'Drowned_God']},
#  {'Gawen_Westerling': ['Gawen_Westerling',
#    'Westerlands',
#    'Sybell_Spicer',
#    'Kevan_Lannister',
#    'Sybell_Spicer',
#    'Jeyne_Westerling',
#    'Martyn_Lannister',
#    'Willem_Lannister',
#    'Jaime_Lannister',
#    'Riverrun',
#    'Jason_Mallister',
#    'Seagard',
#    'Sybell_Spicer',
#    'Rolph_Spicer',
#    'Tywin_Lannister',
#    'Jeyne_Westerling',
#    'Robb_Stark',
#    'House_Lannister',
#    'House_Frey',
#    'Sybell_Spicer',
#    'Raynald_Westerling',
#    'Jeyne_Westerling',
#    'Robb_Stark',
#    'Eleyna_Westerling',
#    'Rollam_Westerling',
#    'Sybell_Spicer',
#    'Kevan_Lannister',
#    'Tyrion_Lannister',
#    'Sybell_Spicer',
#    'Jaime_Lannister']},
#  {'Garth_Greenfield': ['Garth_Greenfield',
#    'Knight',
#    'Knight',
#    'Knight',
#    'House_Lannister',
#    'Riverrun',
#    'Raventree_Hall']},
#  {'Grazdan_mo_Eraz': ['Grazdan_mo_Eraz',
#    'Myr',
#    'Daenerys_Targaryen',
#    'Daenerys_Targaryen',
#    'Daenerys_Targaryen',
#    'Daenerys_Targaryen']},
#  {'Sefton_Staunton': ['Sefton_Staunton',
#    'Aerys_I_Targaryen',
#    'Simon_Staunton',
#    'King%27s_Landing',
#    'Coldmoat',
#    'Simon_Staunton',
#    'Rohanne_Webber',
#    'Rohanne_Webber']},
#  {'Chiggen': ['Chiggen',
#    'Mountains_of_the_Moon',
#    'Bronn',
#    'Bronn',
#    'Catelyn_Stark',
#    'Tyrion_Lannister',
#    'Eyrie',
#    'Mountains_of_the_Moon',
#    'Jaime_Lannister']},
#  {'Draqaz': ['Daenerys_Targaryen',
#    'Skahaz_mo_Kandaq',
#    'Hizdahr_zo_Loraq',
#    'Barristan_Selmy',
#    'Miklaz',
#    'Khrazz']},
#  {'Mullin': ['Mullin', 'Night%27s_Watch', 'Night%27s_Watch', 'Shadow_Tower']},
#  {'Gascoyne': ['Gascoyne',
#    'Greenblood',
#    'Knight',
#    'House_Martell',
#    'Knight',
#    'Trystane_Martell',
#    'Myrcella_Baratheon']},
#  {'Tansy_(orphan)': ['Willow_Heddle']},
#  {'Pate_of_the_Blue_Fork': ['Knight',
#    'House_Frey',
#    'Riverlands',
#    'Amerei_Frey',
#    'Hedge_knight',
#    'Riverlands',
#    'Hedge_knight',
#    'Amerei_Frey',
#    'Merrett_Frey',
#    'Tom_of_Sevenstreams',
#    'Amerei_Frey',
#    'Walder_Frey',
#    'Robb_Stark',
#    'Gregor_Clegane',
#    'Jaime_Lannister',
#    'House_Frey',
#    'Amerei_Frey',
#    'Gregor_Clegane',
#    'Walder_Frey',
#    'Robb_Stark',
#    'Amerei_Frey',
#    'Tom_of_Sevenstreams',
#    'Merrett_Frey',
#    'Gregor_Clegane',
#    'Amerei_Frey',
#    'Jaime_Lannister']},
#  {'Grazdan_zo_Galare': ['Galazza_Galare', 'Daenerys_Targaryen', 'Elza']},
#  {'Pate_(Old)': ['Riverlands',
#    'Riverlands',
#    'Inn_of_the_Kneeling_Man',
#    'House_Lannister',
#    'Arya_Stark',
#    'Gendry',
#    'Hot_Pie',
#    'Tom_of_Sevenstreams']},
#  {'Jorquen': ['Night%27s_Watch', 'Orbert_Caswell']},
#  {'Benjen_Stark_(Bitter)': ['Winterfell',
#    'Winterfell',
#    'House_Stark',
#    'Winterfell']},
#  {'Black_Balaq': ['Golden_Company',
#    'Golden_Company',
#    'Jon_Connington',
#    'Golden_Company',
#    'Aegon_Targaryen_(son_of_Rhaegar)',
#    'Harry_Strickland']},
#  {'Daemon_II_Blackfyre': ['Crownlands',
#    'Daemon_I_Blackfyre',
#    'Hedge_knight',
#    'Seven_Kingdoms',
#    'Daemon_I_Blackfyre',
#    'Alyn_Cockshaw',
#    'Aegon_Blackfyre',
#    'Aemon_Blackfyre',
#    'Kingsguard',
#    'Aegon_V_Targaryen',
#    'Daemon_I_Blackfyre',
#    'Alyn_Cockshaw',
#    'Aegon_Blackfyre',
#    'Aemon_Blackfyre',
#    'First_Blackfyre_Rebellion',
#    'Tyrosh',
#    'Aegor_Rivers',
#    'Gormon_Peake',
#    'Ambrose_Butterwell',
#    'Aegon_V_Targaryen',
#    'Hedge_knight',
#    'Kingsguard',
#    'Gormon_Peake',
#    'Franklyn_Frey',
#    'Galtry_the_Green',
#    'Glendon_Flowers',
#    'Brynden_Rivers',
#    'Aegor_Rivers',
#    'Daena_Targaryen',
#    'Aegon_IV_Targaryen',
#    'Barba_Bracken',
#    'Daemon_I_Blackfyre',
#    'Aegon_Blackfyre',
#    'Aemon_Blackfyre',
#    'Aegor_Rivers',
#    'King%27s_Landing',
#    'Redgrass_Field',
#    'Aerys_I_Targaryen',
#    'Brynden_Rivers',
#    'Gormon_Peake',
#    'Maynard_Plumm',
#    'Brynden_Rivers',
#    'House_Targaryen',
#    'Aegon_I_Targaryen',
#    'Aenys_I_Targaryen',
#    'Maegor_I_Targaryen',
#    'Jaehaerys_I_Targaryen',
#    'Viserys_I_Targaryen',
#    'Aegon_II_Targaryen',
#    'Aegon_III_Targaryen',
#    'Daeron_I_Targaryen',
#    'Baelor_I_Targaryen',
#    'Viserys_II_Targaryen',
#    'Aegon_IV_Targaryen',
#    'Daeron_II_Targaryen',
#    'Aerys_I_Targaryen',
#    'Maekar_I_Targaryen',
#    'Aegon_V_Targaryen',
#    'Jaehaerys_II_Targaryen',
#    'Aerys_II_Targaryen',
#    'House_Baratheon',
#    'Joffrey_Baratheon',
#    'Tommen_Baratheon',
#    'House_Targaryen',
#    'Aegon_Targaryen_(son_of_Aenys_I)',
#    'Rhaenyra_Targaryen',
#    'Viserys_Targaryen',
#    'Daenerys_Targaryen',
#    'Aegon_Targaryen_(son_of_Rhaegar)',
#    'House_Baratheon',
#    'Renly_Baratheon',
#    'Stannis_Baratheon',
#    'Daemon_I_Blackfyre',
#    'Storm_King',
#    'Lyonel_Baratheon',
#    'Balon_Greyjoy',
#    'Balon_Greyjoy',
#    'Euron_Greyjoy',
#    'Robb_Stark']},
#  {'Jon_Arryn': ['Jon_Arryn',
#    'Jon_Arryn',
#    'Hand_of_the_King',
#    'Knight',
#    'Eyrie',
#    'King%27s_Landing',
#    'Lysa_Arryn',
#    'Hand_of_the_King',
#    'Lysa_Arryn',
#    'Robert_Arryn',
#    'Eddard_Stark',
#    'Lysa_Arryn',
#    'Harrold_Hardyng',
#    'Stannis_Baratheon',
#    'King%27s_Landing',
#    'Jasper_Arryn',
#    'Alys_Arryn',
#    'Elys_Waynwood',
#    'Denys_Arryn',
#    'Mountains_of_the_Moon',
#    'Elbert_Arryn',
#    'Eddard_Stark',
#    'Walder_Frey',
#    'Elbert_Arryn',
#    'Aerys_II_Targaryen',
#    'King%27s_Landing',
#    'Eddard_Stark',
#    'Hoster_Tully',
#    'Catelyn_Stark',
#    'Lysa_Arryn',
#    'Denys_Arryn',
#    'Jon_Connington',
#    'Riverrun',
#    'Rhaegar_Targaryen',
#    'Sack_of_King%27s_Landing',
#    'Elia_Martell',
#    'Rhaenys_Targaryen_(daughter_of_Rhaegar)',
#    'Aegon_Targaryen_(son_of_Rhaegar)',
#    'House_Targaryen',
#    'Hand_of_the_King',
#    'Hand_of_the_King',
#    'Dorne',
#    'Lewyn_Martell',
#    'Elia_Martell',
#    'Oberyn_Martell',
#    'Viserys_Targaryen',
#    'Aerys_II_Targaryen',
#    'Sunspear',
#    'Doran_Martell',
#    'Gregor_Clegane',
#    'Amory_Lorch',
#    'Cersei_Lannister',
#    'Jaime_Lannister',
#    'Kingsguard',
#    'Eddard_Stark',
#    'Daenerys_Targaryen',
#    'House_Targaryen',
#    'Seven_Kingdoms',
#    'Nestor_Royce',
#    'Robert_Arryn',
#    'Robert_Arryn',
#    'Petyr_Baelish',
#    'King%27s_Landing',
#    'Hugh',
#    'Mandon_Moore',
#    'Kingsguard',
#    'Malleon',
#    'Colemon',
#    'Lysa_Arryn',
#    'Robert_Arryn',
#    'House_Baratheon',
#    'Tywin_Lannister',
#    'Casterly_Rock',
#    'King%27s_Landing',
#    'Eddard_Stark',
#    'Hand_of_the_King',
#    'Cersei_Lannister',
#    'Jaime_Lannister',
#    'House_Lannister',
#    'Stannis_Baratheon',
#    'Winterfell',
#    'Dragonstone',
#    'Catelyn_Stark',
#    'Eyrie',
#    'Petyr_Baelish',
#    'Varys',
#    'Hugh',
#    'Tobho_Mott',
#    'Gendry',
#    'Barra',
#    'Robert_Arryn',
#    'Malleon',
#    'Pycelle',
#    'House_Lannister',
#    'House_Baratheon',
#    'Joffrey_Baratheon',
#    'Myrcella_Baratheon',
#    'Tommen_Baratheon',
#    'Tyrion_Lannister',
#    'Bran_Stark',
#    'Vardis_Egen',
#    'Bronn',
#    'Riverlands',
#    'Tyrion_Lannister',
#    'Pycelle',
#    'Cersei_Lannister',
#    'Joffrey_Baratheon',
#    'Lysa_Arryn',
#    'Eyrie',
#    'Robert_Arryn',
#    'Dragonstone',
#    'King%27s_Landing',
#    'Colemon',
#    'Sansa_Stark',
#    'Lysa_Arryn',
#    'Petyr_Baelish',
#    'King%27s_Landing',
#    'Robert_Arryn',
#    'Stannis_Baratheon',
#    'Dragonstone',
#    'Catelyn_Stark',
#    'House_Lannister',
#    'House_Stark',
#    'Cersei_Lannister',
#    'Jasper_Arryn',
#    'Lysa_Arryn',
#    'Alys_Arryn',
#    'Elys_Waynwood',
#    'Robert_Arryn',
#    'Denys_Arryn',
#    'Elbert_Arryn',
#    'Harrold_Hardyng',
#    'Eddard_Stark',
#    'Hand_of_the_King',
#    'Eddard_Stark',
# ...
#    'Jon_Snow',
#    'Davos_Seaworth',
#    'Asha_Greyjoy',
#    'Rhaelle_Targaryen',
#    'Steffon_Baratheon',
#    'Cassana_Estermont',
#    'Cersei_Lannister',
#    'Renly_Baratheon',
#    'Margaery_Tyrell',
#    'Selyse_Florent',
#    'Joffrey_Baratheon',
#    'Margaery_Tyrell',
#    'Tommen_Baratheon',
#    'Myrcella_Baratheon',
#    'Shireen_Baratheon',
#    'Mya_Stone',
#    'Bella',
#    'Gendry',
#    'Edric_Storm',
#    'Barra',
#    'House_Targaryen',
#    'Aegon_I_Targaryen',
#    'Aenys_I_Targaryen',
#    'Maegor_I_Targaryen',
#    'Jaehaerys_I_Targaryen',
#    'Viserys_I_Targaryen',
#    'Aegon_II_Targaryen',
#    'Aegon_III_Targaryen',
#    'Daeron_I_Targaryen',
#    'Baelor_I_Targaryen',
#    'Viserys_II_Targaryen',
#    'Aegon_IV_Targaryen',
#    'Daeron_II_Targaryen',
#    'Aerys_I_Targaryen',
#    'Maekar_I_Targaryen',
#    'Aegon_V_Targaryen',
#    'Jaehaerys_II_Targaryen',
#    'Aerys_II_Targaryen',
#    'House_Baratheon',
#    'Joffrey_Baratheon',
#    'Tommen_Baratheon',
#    'House_Targaryen',
#    'Aegon_Targaryen_(son_of_Aenys_I)',
#    'Rhaenyra_Targaryen',
#    'Viserys_Targaryen',
#    'Daenerys_Targaryen',
#    'Aegon_Targaryen_(son_of_Rhaegar)',
#    'House_Baratheon',
#    'Renly_Baratheon',
#    'Daemon_I_Blackfyre',
#    'Daemon_II_Blackfyre',
#    'Storm_King',
#    'Lyonel_Baratheon',
#    'Balon_Greyjoy',
#    'Balon_Greyjoy',
#    'Euron_Greyjoy',
#    'Robb_Stark',
#    'Aegon_I_Targaryen',
#    'Orys_Baratheon',
#    'Addison_Hill',
#    'Edmyn_Tully',
#    'Aenys_I_Targaryen',
#    'Maegor_I_Targaryen',
#    'Murmison',
#    'Maegor_I_Targaryen',
#    'Jaehaerys_I_Targaryen',
#    'Barth',
#    'Lyman_Beesbury',
#    'Ryam_Redwyne',
#    'Otto_Hightower',
#    'Viserys_I_Targaryen',
#    'Lyman_Beesbury',
#    'Criston_Cole',
#    'Otto_Hightower',
#    'Mellos',
#    'Orwyle',
#    'Runciter',
#    'Lyonel_Strong',
#    'Tyland_Lannister',
#    'Larys_Strong',
#    'Ryam_Redwyne',
#    'Daemon_Targaryen',
#    'Harrold_Westerling',
#    'Jasper_Wylde',
#    'Aegon_II_Targaryen',
#    'Criston_Cole',
#    'Otto_Hightower',
#    'Tyland_Lannister',
#    'Orwyle',
#    'Larys_Strong',
#    'Corlys_Velaryon',
#    'Jasper_Wylde',
#    'Aegon_III_Targaryen',
#    'Tyland_Lannister',
#    'Cregan_Stark',
#    'Viserys_II_Targaryen',
#    'Daeron_I_Targaryen',
#    'Viserys_II_Targaryen',
#    'Alyn_Velaryon',
#    'Baelor_I_Targaryen',
#    'Viserys_II_Targaryen',
#    'Aegon_IV_Targaryen',
#    'Daeron_II_Targaryen',
#    'Ambrose_Butterwell',
#    'Baelor_Targaryen_(son_of_Daeron_II)',
#    'Valarr_Targaryen',
#    'Aerys_I_Targaryen',
#    'Brynden_Rivers',
#    'Maekar_I_Targaryen',
#    'Brynden_Rivers',
#    'Aegon_V_Targaryen',
#    'Kaeth',
#    'Pycelle',
#    'Jaehaerys_II_Targaryen',
#    'Gerold_Hightower',
#    'Pycelle',
#    'Aerys_II_Targaryen',
#    'Qarlton_Chelsted',
#    'Jon_Connington',
#    'Gerold_Hightower',
#    'Tywin_Lannister',
#    'Pycelle',
#    'Rossart',
#    'Varys',
#    'Jon_Arryn',
#    'Petyr_Baelish',
#    'Renly_Baratheon',
#    'Pycelle',
#    'Barristan_Selmy',
#    'Eddard_Stark',
#    'Varys',
#    'Cersei_Lannister',
#    'Jaime_Lannister',
#    'Tyrion_Lannister',
#    'Tywin_Lannister',
#    'Oberyn_Martell',
#    'Pycelle',
#    'Petyr_Baelish',
#    'Varys',
#    'Janos_Slynt',
#    'Kevan_Lannister',
#    'Paxter_Redwyne',
#    'Mathis_Rowan',
#    'Mace_Tyrell',
#    'Cersei_Lannister',
#    'Jaime_Lannister',
#    'Kevan_Lannister',
#    'Tywin_Lannister',
#    'Oberyn_Martell',
#    'Orton_Merryweather',
#    'Pycelle',
#    'Qyburn',
#    'Paxter_Redwyne',
#    'Gyles_Rosby',
#    'Nymeria_Sand',
#    'Harys_Swyft',
#    'Randyll_Tarly',
#    'Mace_Tyrell',
#    'Varys',
#    'Aurane_Waters']},
#  {'Guyard_Morrigen': ['Guyard_Morrigen',
#    'Knight',
#    'Rainbow_Guard',
#    'King%27s_Landing',
#    'Knight',
#    'Renly_Baratheon',
#    'Rainbow_Guard',
#    'Renly_Baratheon',
#    'Bitterbridge',
#    'Rainbow_Guard',
#    'Kingsguard',
#    'Stannis_Baratheon',
#    'Storm%27s_End',
#    'Loras_Tyrell',
#    'Storm%27s_End',
#    'Cortnay_Penrose',
#    'King%27s_Landing',
#    'Garlan_Tyrell']},
#  {'Quaithe': ['Quaithe',
#    'Asshai',
#    'Asshai',
#    'Daenerys_Targaryen',
#    'Qarth',
#    'Jhogo',
#    'Xaro_Xhoan_Daxos',
#    'Pyat_Pree',
#    'Daenerys_Targaryen',
#    'Victarion_Greyjoy',
#    'Moqorro',
#    'Tyrion_Lannister',
#    'Jon_Connington',
#    'Quentyn_Martell',
#    'Varys',
#    'Aegon_Targaryen_(son_of_Rhaegar)',
#    'Daenerys_Targaryen',
#    'Daenerys_Targaryen',
#    'Jorah_Mormont',
#    'Daenerys_Targaryen',
#    'Rakharo',
#    'Daenerys_Targaryen']},
#  {'Quincy_Cox': ['Quincy_Cox',
#    'Sandor_Clegane',
#    'Rorge',
#    'Brave_Companions',
#    'Biter',
#    'Meribald',
#    'Elder_Brother_(Quiet_Isle)']},
#  {'Styr': ['Styr',
#    'Free_folk',
#    'Castle_Black',
#    'Free_folk',
#    'Mance_Rayder',
#    'Jon_Snow',
#    'Mance_Rayder',
#    'Jarl',
#    'Castle_Black',
#    'Night%27s_Watch',
#    'Jon_Snow']},
#  {'Olymer_Tyrell': ['Olymer_Tyrell',
#    'Lysa_Meadows',
#    'Quentin_Tyrell',
#    'Lysa_Meadows',
#    'Raymund_Tyrell',
#    'Rickard_Tyrell',
#    'Megga_Tyrell',
#    'Luthor_Tyrell',
#    'Gormon_Tyrell',
#    'Garth_Tyrell',
#    'Moryn_Tyrell',
#    'Mace_Tyrell',
#    'Alerie_Hightower',
#    'Jon_Fossoway',
#    'Mina_Tyrell',
#    'Paxter_Redwyne',
#    'Garse_Flowers',
#    'Garrett_Flowers',
#    'Luthor_Tyrell_(son_of_Moryn)',
#    'Elyn_Norridge',
#    'Willas_Tyrell',
#    'Garlan_Tyrell',
#    'Leonette_Fossoway',
#    'Horas_Redwyne',
#    'Hobber_Redwyne',
#    'Lia_Serry',
#    'Theodore_Tyrell',
#    'Olene_Tyrell',
#    'Leo_Blackbar',
#    'Medwick_Tyrell',
#    'Loras_Tyrell',
#    'Renly_Baratheon',
#    'Margaery_Tyrell',
#    'Joffrey_Baratheon',
#    'Elinor_Tyrell',
#    'Luthor_Tyrell_(son_of_Theodore)',
#    'Tommen_Baratheon',
#    'Quentin_Tyrell',
#    'Normund_Tyrell',
#    'Victor_Tyrell',
#    'Lysa_Meadows',
#    'Jon_Bulwer',
#    'Victaria_Tyrell',
#    'Leo_Tyrell_(son_of_Victor)',
#    'Raymund_Tyrell',
#    'Rickard_Tyrell',
#    'Megga_Tyrell',
#    'Alysanne_Bulwer',
#    'Lyonel_Tyrell_(son_of_Leo)',
#    'Alla_Tyrell',
#    'Lucas_Tyrell',
#    'Lorent_Tyrell',
#    'Leona_Tyrell']},
#  {'Lancel_V_Lannister': ['Lancel_V_Lannister',
#    'House_Lannister',
#    'King_of_the_Rock',
#    'House_Lannister',
#    'King_of_the_Rock',
#    'Eustace_Osgrey',
#    'Wilbert_Osgrey']},
#  {'Martyn_Mullendore': ['Martyn_Mullendore']},
#  {'Pate_(Night%27s_Watch)': ['Night%27s_Watch', 'Night%27s_Watch', 'Halder']},
#  {'Lucas_Nayland': ['Knight', 'Knight', 'Aerys_I_Targaryen', 'Kirby_Pimm']},
#  {'Moro_(Century_of_Blood)': ['Dothraki', 'Dothraki', 'Dothraki']},
#  {'Grazdan_mo_Ullhor': ['Grazdan_mo_Ullhor',
#    'Cleon',
#    'Daenerys_Targaryen',
#    'Unsullied',
#    'Rakharo']},
#  {'Lyonel_Strong': ['Lyonel_Strong',
#    'Hand_of_the_King',
#    'Harrenhal',
#    'Harrenhal',
#    'Hand_of_the_King',
#    'Viserys_I_Targaryen',
#    'Harwin_Strong',
#    'Larys_Strong',
#    'Citadel',
#    'Harrenhal',
#    'Jaehaerys_I_Targaryen',
#    'Viserys_I_Targaryen',
#    'Otto_Hightower',
#    'Hand_of_the_King',
#    'Daemon_Targaryen',
#    'Rhaenyra_Targaryen',
#    'Eustace_(Dance_of_the_Dragons)',
#    'Harrenhal',
#    'Harwin_Strong',
#    'Corlys_Velaryon',
#    'Larys_Strong',
#    'Harwin_Strong',
#    'Larys_Strong',
#    'Hand_of_the_King',
#    'Orys_Baratheon',
#    'Edmyn_Tully',
#    'Maegor_I_Targaryen',
#    'Murmison',
#    'Barth',
#    'Ryam_Redwyne',
#    'Otto_Hightower',
#    'Otto_Hightower',
#    'Criston_Cole',
#    'Cregan_Stark',
#    'Tyland_Lannister',
#    'Viserys_II_Targaryen',
#    'Ambrose_Butterwell',
#    'Baelor_Targaryen_(son_of_Daeron_II)',
#    'Valarr_Targaryen',
#    'Brynden_Rivers',
#    'Tywin_Lannister',
#    'Jon_Connington',
#    'Qarlton_Chelsted',
#    'Rossart',
#    'Jon_Arryn',
#    'Eddard_Stark',
#    'Tyrion_Lannister',
#    'Tywin_Lannister',
#    'Harys_Swyft',
#    'Orton_Merryweather',
#    'Mace_Tyrell',
#    'Corlys_Velaryon',
#    'Mace_Tyrell',
#    'Alester_Florent',
#    'Davos_Seaworth',
#    'Axell_Florent',
#    'Jon_Connington',
#    'Barristan_Selmy',
#    'Myles_Smallwood',
#    'Aegon_I_Targaryen',
#    'Orys_Baratheon',
#    'Addison_Hill',
#    'Edmyn_Tully',
#    'Aenys_I_Targaryen',
#    'Maegor_I_Targaryen',
#    'Murmison',
#    'Maegor_I_Targaryen',
#    'Jaehaerys_I_Targaryen',
#    'Barth',
#    'Lyman_Beesbury',
#    'Ryam_Redwyne',
#    'Otto_Hightower',
#    'Viserys_I_Targaryen',
#    'Lyman_Beesbury',
#    'Criston_Cole',
#    'Otto_Hightower',
#    'Mellos',
#    'Orwyle',
#    'Runciter',
#    'Tyland_Lannister',
#    'Larys_Strong',
#    'Ryam_Redwyne',
#    'Daemon_Targaryen',
#    'Harrold_Westerling',
#    'Jasper_Wylde',
#    'Aegon_II_Targaryen',
#    'Criston_Cole',
#    'Otto_Hightower',
#    'Tyland_Lannister',
#    'Orwyle',
#    'Larys_Strong',
#    'Corlys_Velaryon',
#    'Jasper_Wylde',
#    'Aegon_III_Targaryen',
#    'Tyland_Lannister',
#    'Cregan_Stark',
#    'Viserys_II_Targaryen',
#    'Daeron_I_Targaryen',
#    'Viserys_II_Targaryen',
#    'Alyn_Velaryon',
#    'Baelor_I_Targaryen',
#    'Viserys_II_Targaryen',
#    'Aegon_IV_Targaryen',
#    'Daeron_II_Targaryen',
#    'Ambrose_Butterwell',
#    'Baelor_Targaryen_(son_of_Daeron_II)',
#    'Valarr_Targaryen',
#    'Aerys_I_Targaryen',
#    'Brynden_Rivers',
#    'Maekar_I_Targaryen',
#    'Brynden_Rivers',
#    'Aegon_V_Targaryen',
#    'Kaeth',
#    'Pycelle',
#    'Jaehaerys_II_Targaryen',
#    'Gerold_Hightower',
#    'Pycelle',
#    'Aerys_II_Targaryen',
#    'Qarlton_Chelsted',
#    'Jon_Connington',
#    'Gerold_Hightower',
#    'Tywin_Lannister',
#    'Pycelle',
#    'Rossart',
#    'Varys',
#    'Jon_Arryn',
#    'Petyr_Baelish',
#    'Renly_Baratheon',
#    'Stannis_Baratheon',
#    'Pycelle',
#    'Barristan_Selmy',
#    'Eddard_Stark',
#    'Varys',
#    'Cersei_Lannister',
#    'Jaime_Lannister',
#    'Tyrion_Lannister',
#    'Tywin_Lannister',
#    'Oberyn_Martell',
#    'Pycelle',
#    'Petyr_Baelish',
#    'Varys',
#    'Janos_Slynt',
#    'Kevan_Lannister',
#    'Paxter_Redwyne',
#    'Mathis_Rowan',
#    'Mace_Tyrell',
#    'Cersei_Lannister',
#    'Jaime_Lannister',
#    'Kevan_Lannister',
#    'Tywin_Lannister',
#    'Oberyn_Martell',
#    'Orton_Merryweather',
#    'Pycelle',
#    'Qyburn',
#    'Paxter_Redwyne',
#    'Gyles_Rosby',
#    'Nymeria_Sand',
#    'Harys_Swyft',
#    'Randyll_Tarly',
#    'Mace_Tyrell',
#    'Varys',
#    'Aurane_Waters']},
#  {'Yohn_Farwynd': ['Yohn_Farwynd', 'Gylbert_Farwynd']},
#  {'Walder_Frey': ['Walder_Frey',
#    'House_Frey',
#    'Cyrenna_Swann',
#    'Amarei_Crakehall',
#    'Alyssa_Blackwood',
#    'Sarya_Whent',
#    'Bethany_Rosby',
#    'Annara_Farring',
#    'Joyeuse_Erenford',
#    'House_Frey',
#    'Hoster_Tully',
#    'Ambrose_Butterwell',
#    'Tytos_Lannister',
#    'Emmon_Frey',
#    'Genna_Lannister',
#    'Tywin_Lannister',
#    'Hoster_Tully',
#    'Jon_Arryn',
#    'King%27s_Landing',
#    'Robert_Arryn',
#    'Hoster_Tully',
#    'Edmure_Tully',
#    'Annara_Farring',
#    'House_Frey',
#    'Catelyn_Stark',
#    'Hoster_Tully',
#    'Joyeuse_Erenford',
#    'Tyrion_Lannister',
#    'House_Tully',
#    'Edmure_Tully',
#    'Addam_Marbrand',
#    'House_Lannister',
#    'House_Frey',
#    'Jaime_Lannister',
#    'Robb_Stark',
#    'Arya_Stark',
#    'Elmar_Frey',
#    'Walder_Frey_(son_of_Merrett)',
#    'Walder_Frey_(son_of_Jammos)',
#    'Winterfell',
#    'Olyvar_Frey',
#    'Stevron_Frey',
#    'Roose_Bolton',
#    'Walda_Frey_(daughter_of_Merrett)',
#    'Jeyne_Westerling',
#    'Ryman_Frey',
#    'Lothar_Frey',
#    'Riverrun',
#    'Edmure_Tully',
#    'Roslin_Frey',
#    'Catelyn_Stark',
#    'Tywin_Lannister',
#    'Joffrey_Baratheon',
#    'Emmon_Frey',
#    'Merrett_Frey',
#    'Stevron_Frey',
#    'Petyr_Frey',
#    'Brotherhood_without_banners',
#    'Daven_Lannister',
#    'Lancel_Lannister',
#    'Amerei_Frey',
#    'King%27s_Landing',
#    'Cersei_Lannister',
#    'Elder_Brother_(Quiet_Isle)',
#    'Quiet_Isle',
#    'Ryman_Frey',
#    'Jaime_Lannister',
#    'Walder_Rivers',
#    'Tommen_Baratheon',
#    'Wyman_Manderly',
#    'Rhaegar_Frey',
#    'Walder_Frey_(son_of_Merrett)',
#    'Wynafryd_Manderly',
#    'Wylla_Manderly',
#    'Aenys_Frey',
#    'Hosteen_Frey',
#    'Jared_Frey',
#    'Symond_Frey',
#    'White_Harbor',
#    'Winterfell',
#    'Ryger_Rivers',
#    'Hoster_Tully',
#    'Edmure_Tully',
#    'Catelyn_Stark',
#    'Jared_Frey',
#    'Tywin_Lannister',
#    'Eddard_Stark',
#    'Hoster_Tully',
#    'Jaime_Lannister',
#    'Edmure_Tully',
#    'Robb_Stark',
#    'Catelyn_Stark',
#    'Stannis_Baratheon',
#    'Tywin_Lannister',
#    'Catelyn_Stark',
#    'Robb_Stark',
#    'Robb_Stark',
#    'Riverrun',
#    'Tyrion_Lannister',
#    'Catelyn_Stark',
#    'Robett_Glover',
#    'Catelyn_Stark',
#    'Hoster_Tully',
#    'Seven_Kingdoms',
#    'Catelyn_Stark',
#    'Catelyn_Stark',
#    'Edmure_Tully',
#    'Catelyn_Stark',
#    'Joyeuse_Erenford',
#    'Tyrion_Lannister',
#    'Tywin_Lannister',
#    'Cersei_Lannister',
#    'Franklyn_Frey',
#    'Ambrose_Butterwell',
#    'Addam_Frey',
#    'Stevron_Frey',
#    'Stevron_Frey',
#    'Marsella_Waynwood',
#    'Jeyne_Lydden',
#    'Ryman_Frey',
#    'Aegon_Frey_(son_of_Stevron)',
#    'Maegelle_Frey',
#    'Dafyn_Vance',
#    'Walton_Frey',
#    'Deana_Hardyng',
#    'Edwyn_Frey',
#    'Walder_Frey_(son_of_Ryman)',
#    'Petyr_Frey',
#    'Mylenda_Caron',
#    'Marianne_Vance',
#    'Walder_Vance',
#    'Patrek_Vance',
#    'Steffon_Frey',
#    'Walda_Frey_(daughter_of_Walton)',
#    'Bryan_Frey',
#    'Walda_Frey_(daughter_of_Edwyn)',
#    'Perra_Frey',
#    'Emmon_Frey',
#    'Emmon_Frey',
#    'Genna_Lannister',
#    'Cleos_Frey',
#    'Jeyne_Darry',
#    'Lyonel_Frey',
#    'Melesa_Crakehall',
#    'Tion_Frey',
#    'Walder_Frey_(son_of_Emmon)',
#    'Tywin_Frey',
#    'Willem_Frey',
#    'Aenys_Frey',
#    'Perriane_Frey',
#    'Aenys_Frey',
#    'Tyana_Wylde',
#    'Perriane_Frey',
#    'Leslyn_Haigh',
#    'Aegon_Frey_(son_of_Aenys)',
#    'Rhaegar_Frey',
#    'Jeyne_Beesbury',
#    'Harys_Haigh',
#    'Donnel_Haigh',
#    'Alyn_Haigh',
#    'Robert_Frey',
#    'Walda_Frey_(daughter_of_Rhaegar)',
#    'Jonos_Frey',
#    'Walder_Haigh',
#    'Cyrenna_Swann',
#    'Jared_Frey',
#    'Alys_Frey',
#    'Luceon_Frey',
#    'Tytos_Frey',
#    'Zhoe_Blanetree',
#    'Garse_Goodbrook',
#    'Kyra_Frey',
#    'Zia_Frey',
#    'Zachery_Frey',
#    'Walder_Goodbrook',
#    'Jeyne_Goodbrook',
#    'Amarei_Crakehall',
#    'Hosteen_Frey',
#    'Bellena_Hawick',
#    'Lucias_Vypren',
#    'Lythene_Frey',
#    'Symond_Frey',
#    'Betharios_of_Braavos',
#    'Danwell_Frey',
#    'Wynafrei_Whent',
#    'Arwood_Frey',
#    'Ryella_Royce',
#    'Damon_Vypren',
#    'Elyana_Vypren',
#    'Jon_Wylde',
#    'Alesander_Frey',
#    'Alyx_Frey',
#    'Bradamar_Frey',
#    'Ryella_Frey',
#    'Androw_Frey',
#    'Alyn_Frey',
#    'Rickard_Wylde',
#    'Merrett_Frey',
#    'Mariya_Darry',
#    'Carolei_Waynwood',
#    'Pate_of_the_Blue_Fork',
#    'Amerei_Frey',
#    'Lancel_Lannister',
#    'Walda_Frey_(daughter_of_Merrett)',
#    'Roose_Bolton',
#    'Marissa_Frey',
#    'Walder_Frey_(son_of_Merrett)',
#    'Sandor_Frey',
#    'Cynthea_Frey',
#    'Raymund_Frey',
#    'Robert_Frey_(son_of_Raymund)',
#    'Malwyn_Frey',
#    'Sarra_Frey',
#    'Serra_Frey',
#    'Cersei_Frey',
#    'Tywin_Frey_(son_of_Raymund)',
#    'Jaime_Frey',
#    'Alyssa_Blackwood',
#    'Lothar_Frey',
#    'Leonella_Lefford',
#    'Jammos_Frey',
#    'Sallei_Paege',
#    'Whalen_Frey',
#    'Sylwa_Paege',
#    'Morya_Frey',
#    'Flement_Brax',
#    'Tyta_Frey',
#    'Walder_Frey_(son_of_Jammos)',
#    'Dickon_Frey',
#    'Mathis_Frey',
#    'Robert_Brax_(son_of_Flement)',
#    'Walder_Brax',
#    'Jon_Brax',
#    'Tysane_Frey',
#    'Walda_Frey_(daughter_of_Lothar)',
#    'Emberlei_Frey',
#    'Leana_Frey',
#    'Hoster_Frey',
#    'Merianne_Frey',
#    'Bethany_Rosby',
#    'Perwyn_Frey',
#    'Benfrey_Frey',
#    'Jyanna_Frey',
#    'Willamen_Frey',
#    'Olyvar_Frey',
#    'Roslin_Frey',
#    'Edmure_Tully',
#    'Della_Frey',
#    'Osmund_Frey',
#    'Annara_Farring',
#    'Arwyn_Frey',
#    'Wendel_Frey',
#    'Colmar_Frey',
#    'Waltyr_Frey',
#    'Elmar_Frey',
#    'Shirei_Frey',
#    'Walder_Rivers',
#    'Walda_Rivers',
#    'Aemon_Rivers',
#    'Walda_Rivers_(daughter_of_Aemon)']},
#  {'Rhialta_Vance': ['Rhialta_Vance',
#    'Karyl_Vance',
#    'Karyl_Vance',
#    'Liane_Vance',
#    'Emphyria_Vance']},
#  {'Tanton_Fossoway': ['Tanton_Fossoway',
#    'Knight',
#    'House_Fossoway_of_Cider_Hall',
#    'Knight',
#    'House_Fossoway_of_Cider_Hall',
#    'Renly_Baratheon',
#    'Bitterbridge',
#    'Sandor_Clegane',
#    'Joffrey_Baratheon']},
#  {'Robyn_Rhysling': ['Robyn_Rhysling',
#    'Knight',
#    'The_Hedge_Knight',
#    'Knight',
#    'Daeron_II_Targaryen',
#    'Tourney_at_Ashford_Meadow',
#    'Leo_Tyrell_(Longthorn)',
#    'Aegon_V_Targaryen',
#    'Daeron_Targaryen_(son_of_Maekar_I)',
#    'The_Hedge_Knight']},
#  {'Larra_Blackmont': ['Larra_Blackmont',
#    'Perros_Blackmont',
#    'Jynessa_Blackmont',
#    'Oberyn_Martell',
#    'King%27s_Landing',
#    'Jynessa_Blackmont',
#    'Perros_Blackmont']},
#  {'Sylas': ['Sylas', 'Pyke', 'Theon_Greyjoy', 'Pyke']},
#  ...]

# %% [markdown]
# # Read the chapters and the book they belong to
# The books have been cut into chapters themselves into a book directory named GOT{x} where x is the book in order of publication. We read the whole directory to retain only text files. we create a chapter list containing the text of the chapter and the book index

# %%
import os
from os.path import join

chapters = []

for root, dirs, files in os.walk('Downloads/US01-test-master/data'):
    for name in files:
        if name.endswith('txt'):
            book = int(root.split('/')[-1][-1:])
            with open(join(root,name),'r') as fp:
                chapters.append((book,fp.read()))
book               
print('found',len(chapters),'chapters')
#print(chapters[1])
# Out:
# found 345 chapters

# %% [markdown]
# # For each Chapter, we analyze the entities and prepare the sentences¶
# Each chapter contains some Persons, that might be characters. We save them and their position together with the book they belong to. This will allow us to
#
# get a distance between persons
# disambiguate the characters using the book they appear in to

# %%
def getCandidates(name, shortened, key, equal=True):
    candidates=[]
    for s in shortened:
        if key != 'aliases'
            if equal:
                if name == s[key]:
                    candidates.append(s)
                elif name in s[key]:
                    candidates.append(s)
                
    if len(candidates) > 0:
        return candidates[0]['common_name']
    
    else:
        None
                 
def lemmatize(name, book):
    #add a character to the list if he is in the same book according to the 
    #function argument and wiki
    shortened=[]
    for c in characters:
        if c['books'] is not None:
            if book in c['books']:
                shortened.append(c)
                
    candidate = getCandidates(name, shortened, 'common_name')
        if candidate is not None :
            return candidate
        
    candidate = getCandidates(name, shortened, 'short_name')
        if candidate is not None :
            return candidate
        
    candidate = getCandidates(name, shortened, 'fullname')
        if candidate is not None :
            return candidate
        
    candidate = getCandidates(name, shortened, 'alias')
        if candidate is not None :
            return candidate
            
                
    
    return None

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
import networkx as nx

STOPLIST = set(["n't", "'s", "'m", "ca"] + list(STOP_WORDS))
#SYMBOLS = " ".join(string.punctuation).split(" ") + ["-----", "---", "...", "“", "”", '\t','\n']
nlp = spacy.load('en_core_web_sm')

characters = {}
sentences = [] 
for i in range(len(chapters)):
    if i > 2:
        break
    book, chapter = chapters[i]
    chapter = chapter.strip().replace("\n", " ").replace("\t", " ")
    doc = nlp(chapter)

    for ent in doc.ents:
        if ent.label_ == 'PERSON':
            entity = ent.text.replace("'s",'')
            if ent.text not in characters.keys():
                characters[entity] = {'books':set(),'positions':[]}
            
            characters[entity]['books'].add(book)
            characters[entity]['positions'].append((ent.start, ent.end))
            ent.merge(ent.root.tag_,ent.text, ent.label_)

#Remove useless thing such as punctuation

    sentence = []
    for token in doc:
       #print(token.ent_type_, token.text, token.pos_)
        if token.ent_type_ == 'PERSON':
            text = token.text.replace(' ', '_').replace("'s",'')
            tag = token.ent_type_
            sentence.append('%s|%s' % (text, tag))
        elif token.pos_ not in ['PUNCT','SPACE']:
            sentence.append(token.lemma_.strip() if token.lemma_ != "-PRON-" else token.lower_)
        elif token.pos_ == 'PUNCT' and token.text == '.':
            sentences.append(sentence)
            sentences.append([word for word in sentence if word not in STOPLIST])
            sentence = []

print(characters.keys())

# %%
from gensim.models import Word2Vec
model = Word2Vec(sentences, size=50, window=5, min_count=1, workers=4)
model.wv.most_similar('Bran|PERSON')

# %%
import itertools
couples = list(itertools.combinations(characters, 2))
G.add_edges_from(couples)

# %%
print(nx.info(G))
nx.write_gexf(G, 'one-chapter.gexf')
